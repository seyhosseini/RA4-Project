# %%
#### Now have these colummns
### create a new column labeled DPM-Exists (TRUE or FALSE)
### what does expiration and inspiration mean? Related to (RV, TLC)? follow up with Patrick or Eric Hoffman
### Found "nan" values for the SPI-MU161671 case

# %%
def PrintNeatSO(SO):
    # Convert numeric values to strings and find the maximum length
    max_length = max(len(str(cell)) for row in SO for cell in row)

    # Print the matrix with aligned columns
    for row in SO:
        row_str = "  ".join(str(cell).ljust(max_length) for cell in row)
        print(row_str)

# %%
import pandas as pd

# List to store data
AP = []

# List of sheet names
sheet_names = ['APK-List-V1', 'APK-List-V2', 'APK-List-V3-PRM', 'APK-List-V3-LNC', 'APK-List-V5']

# Iterate through sheets
for sheet_name in sheet_names:
    # Read data from the sheet
    df = pd.read_excel('./TablesPublication(TEMP)/T6-SPI-MIL-AP-OnlyModifyOnlineVersion.xlsx', sheet_name=sheet_name)
    
    # Get the specific rows you need (adjust column indexes as needed)
    if sheet_name == 'APK-List-V2': MixedColumns = df.iloc[:, [1, 3, 5]].values.tolist()
    else: MixedColumns = df.iloc[:, [1, 3, 4]].values.tolist()
    
    # Append rows to AP
    AP.append(MixedColumns)

   # Print the element from the first sheet (index 0) at row 2 (index 1)
for I in AP[0][0]: 
    print("AP:", I)

########################################################################################################################

# Creates the MIL List which has all Image Data Needed
# List to store data
MIL = []

# List of sheet names
sheet_names = ['SPIROMICS-Columns-Trimmed']

# Iterate through sheets
for sheet_name in sheet_names:
    # Read data from the sheet
    df = pd.read_excel('./TablesPublication(TEMP)/T6-SPI-MIL-AP-OnlyModifyOnlineVersion.xlsx', sheet_name=sheet_name)
    
    # Get the specific rows you need (adjust column indexes as needed)
    columns = df.iloc[:, [3, 4, 5, 7]].values.tolist()
    
    # Append rows to AP
    MIL.append(columns)

   # Print the element from the first sheet (index 0) at row 2 (index 1)
for I in MIL[0][0]: 
    print("MIL:", I)

#########################################################################################################################

# Creates the IS List which has all Image Data Needed
# List to store data
ISS = []

# List of sheet names
sheet_names = 'B-CasesTable'

# Read data from the sheet
df = pd.read_excel('./TablesPublication(TEMP)/T7-Summary-OnlyModifyOnlineVersion.xlsx', sheet_name=sheet_names)

# Get the specific rows you need (adjust column indexes as needed)
ISS = df.iloc[:,3].tolist()

# Remove nans and DUPs # And get rid of mesa cases right now
IS = []
for whtr in ISS:
    if isinstance(whtr, str) and whtr != 'DUP' and "MESA" not in whtr:     # GET RID OF MESA CASES NOW
        IS.append(whtr)

# Print the element from the first sheet (index 0) at row 2 (index 1)
IS
# Out:
# AP: H-14352
# AP: SPI-WF120113-V1
# AP: TLC
# MIL: H-29737
# MIL: SPI-NJ221261-V5
# MIL: V5
# MIL: RV
# ['SPI-JH110088',
#  'SPI-JH110704',
#  'SPI-JH112953',
#  'SPI-JH115247',
#  'SPI-JH114663',
#  'SPI-IA210102',
#  'SPI-JH110280',
#  'SPI-JH115627',
#  'SPI-JH112358',
#  'SPI-IA210599',
#  'SPI-JH112648',
#  'SPI-IA210257',
#  'SPI-IA210637',
#  'SPI-IA210520',
#  'SPI-JH114016',
#  'SPI-JH115778',
#  'SPI-IA210428',
#  'SPI-IA210305',
#  'SPI-IA210273',
#  'SPI-JH114615',
#  'SPI-JH111728',
#  'SPI-IA210196',
#  'SPI-IA210285',
#  'SPI-MU163450',
#  'SPI-JH115593',
#  'SPI-JH111894',
#  'SPI-JH112757',
#  'SPI-MU164552',
#  'SPI-MU164261',
#  'SPI-JH114008',
#  'SPI-JH113081',
#  'SPI-JH114158',
#  'SPI-JH111913',
#  'SPI-JH114303',
#  'SPI-JH112683',
#  'SPI-IA210545',
#  'SPI-JH115746',
#  'SPI-JH114090',
#  'SPI-JH111112',
#  'SPI-JH114588',
#  'SPI-IA210649',
#  'SPI-IA210581',
#  'SPI-JH111791',
#  'SPI-JH112431',
#  'SPI-JH112455',
#  'SPI-JH112708',
#  'SPI-JH114311',
#  'SPI-IA210581',
#  'SPI-MU161671']

# %%
# SO Matrix Formation
#  Creates SO which will be filled with the appropriate data

rows = len(IS)+1
columns = 8

# Create a matrix filled with "NFY"
SO = [[[] for _ in range(columns)] for _ in range(rows)]

# Append "SPI-..." to the cell at row 0 and column 0
SO[0][0] = "SPI-..."
SO[0][1] = "RV IM"
SO[0][2] = "TLC IM"
SO[0][3] = "TLC AP"
SO[0][4] = "RV AP"
SO[0][5] = "TLC/RV IM"
SO[0][6] = "TLC/RV AP"
SO[0][7] = "FRC IM"

# Adds the Is list to column 1 (index 0) of the SO Matrix

column_index = 1
for value in IS:
    if column_index >= len(SO):
        break  # Stop if you've filled all available rows
    SO[column_index][0] = value  # Set the value in the first column
    column_index += 1

PrintNeatSO(SO)
# Out:
# SPI-...       RV IM         TLC IM        TLC AP        RV AP         TLC/RV IM     TLC/RV AP     FRC IM
# SPI-JH110088  []            []            []            []            []            []            []
# SPI-JH110704  []            []            []            []            []            []            []
# SPI-JH112953  []            []            []            []            []            []            []
# SPI-JH115247  []            []            []            []            []            []            []
# SPI-JH114663  []            []            []            []            []            []            []
# SPI-IA210102  []            []            []            []            []            []            []
# SPI-JH110280  []            []            []            []            []            []            []
# SPI-JH115627  []            []            []            []            []            []            []
# SPI-JH112358  []            []            []            []            []            []            []
# SPI-IA210599  []            []            []            []            []            []            []
# SPI-JH112648  []            []            []            []            []            []            []
# SPI-IA210257  []            []            []            []            []            []            []
# SPI-IA210637  []            []            []            []            []            []            []
# SPI-IA210520  []            []            []            []            []            []            []
# SPI-JH114016  []            []            []            []            []            []            []
# SPI-JH115778  []            []            []            []            []            []            []
# SPI-IA210428  []            []            []            []            []            []            []
# SPI-IA210305  []            []            []            []            []            []            []
# SPI-IA210273  []            []            []            []            []            []            []
# SPI-JH114615  []            []            []            []            []            []            []
# SPI-JH111728  []            []            []            []            []            []            []
# SPI-IA210196  []            []            []            []            []            []            []
# SPI-IA210285  []            []            []            []            []            []            []
# SPI-MU163450  []            []            []            []            []            []            []
# SPI-JH115593  []            []            []            []            []            []            []
# SPI-JH111894  []            []            []            []            []            []            []
# SPI-JH112757  []            []            []            []            []            []            []
# SPI-MU164552  []            []            []            []            []            []            []
# SPI-MU164261  []            []            []            []            []            []            []
# SPI-JH114008  []            []            []            []            []            []            []
# SPI-JH113081  []            []            []            []            []            []            []
# SPI-JH114158  []            []            []            []            []            []            []
# SPI-JH111913  []            []            []            []            []            []            []
# SPI-JH114303  []            []            []            []            []            []            []
# SPI-JH112683  []            []            []            []            []            []            []
# SPI-IA210545  []            []            []            []            []            []            []
# SPI-JH115746  []            []            []            []            []            []            []
# SPI-JH114090  []            []            []            []            []            []            []
# SPI-JH111112  []            []            []            []            []            []            []
# SPI-JH114588  []            []            []            []            []            []            []
# SPI-IA210649  []            []            []            []            []            []            []
# SPI-IA210581  []            []            []            []            []            []            []
# SPI-JH111791  []            []            []            []            []            []            []
# SPI-JH112431  []            []            []            []            []            []            []
# SPI-JH112455  []            []            []            []            []            []            []
# SPI-JH112708  []            []            []            []            []            []            []
# SPI-JH114311  []            []            []            []            []            []            []
# SPI-IA210581  []            []            []            []            []            []            []
# SPI-MU161671  []            []            []            []            []            []            []

# %%
### Adds IS to SO
# Inputs IS into the SO matrix in column 1

IS
for i in range(len(IS)):
    SO[i+1][0] = IS[i]

# Convert numeric values to strings and find the maximum length
max_length = max(len(str(cell)) for row in SO for cell in row)

# Print the matrix with aligned columns
for row in SO:
    row_str = "  ".join(str(cell).ljust(max_length) for cell in row)
    print(row_str)
# Out:
# SPI-...       RV IM         TLC IM        TLC AP        RV AP         TLC/RV IM     TLC/RV AP     FRC IM
# SPI-JH110088  []            []            []            []            []            []            []
# SPI-JH110704  []            []            []            []            []            []            []
# SPI-JH112953  []            []            []            []            []            []            []
# SPI-JH115247  []            []            []            []            []            []            []
# SPI-JH114663  []            []            []            []            []            []            []
# SPI-IA210102  []            []            []            []            []            []            []
# SPI-JH110280  []            []            []            []            []            []            []
# SPI-JH115627  []            []            []            []            []            []            []
# SPI-JH112358  []            []            []            []            []            []            []
# SPI-IA210599  []            []            []            []            []            []            []
# SPI-JH112648  []            []            []            []            []            []            []
# SPI-IA210257  []            []            []            []            []            []            []
# SPI-IA210637  []            []            []            []            []            []            []
# SPI-IA210520  []            []            []            []            []            []            []
# SPI-JH114016  []            []            []            []            []            []            []
# SPI-JH115778  []            []            []            []            []            []            []
# SPI-IA210428  []            []            []            []            []            []            []
# SPI-IA210305  []            []            []            []            []            []            []
# SPI-IA210273  []            []            []            []            []            []            []
# SPI-JH114615  []            []            []            []            []            []            []
# SPI-JH111728  []            []            []            []            []            []            []
# SPI-IA210196  []            []            []            []            []            []            []
# SPI-IA210285  []            []            []            []            []            []            []
# SPI-MU163450  []            []            []            []            []            []            []
# SPI-JH115593  []            []            []            []            []            []            []
# SPI-JH111894  []            []            []            []            []            []            []
# SPI-JH112757  []            []            []            []            []            []            []
# SPI-MU164552  []            []            []            []            []            []            []
# SPI-MU164261  []            []            []            []            []            []            []
# SPI-JH114008  []            []            []            []            []            []            []
# SPI-JH113081  []            []            []            []            []            []            []
# SPI-JH114158  []            []            []            []            []            []            []
# SPI-JH111913  []            []            []            []            []            []            []
# SPI-JH114303  []            []            []            []            []            []            []
# SPI-JH112683  []            []            []            []            []            []            []
# SPI-IA210545  []            []            []            []            []            []            []
# SPI-JH115746  []            []            []            []            []            []            []
# SPI-JH114090  []            []            []            []            []            []            []
# SPI-JH111112  []            []            []            []            []            []            []
# SPI-JH114588  []            []            []            []            []            []            []
# SPI-IA210649  []            []            []            []            []            []            []
# SPI-IA210581  []            []            []            []            []            []            []
# SPI-JH111791  []            []            []            []            []            []            []
# SPI-JH112431  []            []            []            []            []            []            []
# SPI-JH112455  []            []            []            []            []            []            []
# SPI-JH112708  []            []            []            []            []            []            []
# SPI-JH114311  []            []            []            []            []            []            []
# SPI-IA210581  []            []            []            []            []            []            []
# SPI-MU161671  []            []            []            []            []            []            []

# %%
SO[1][0]
# Out:
# 'SPI-JH110088'

# %%
### Keyword index in MIL
#This finds all of the indicies for where the the keyword is present in the MIL list

keyword = "SPI-JH110088"  

def search_and_print_indices(keyword, data_list):
    found_indices = []
    
    for idx, row in enumerate(data_list[0]):
        if keyword in row[1]:  # Assuming the second column is at index 1
            found_indices.append(idx)
    
    if found_indices:
        print(f"Keyword '{keyword}' found at indices: {found_indices}")
    else:
        print(f"Keyword '{keyword}' not found in the list.")

# Example data_list structure: 1x16000x3
data_list = MIL
 

search_and_print_indices(keyword, data_list)
# Out:
# Keyword 'SPI-JH110088' found at indices: [15548, 15549, 15550, 15551, 15552, 15553, 15554, 15555, 15556, 15557, 15558, 15559, 15560, 15561, 15562, 15563, 15564, 15565, 15566, 15567, 15568, 15569, 15570, 15571]

# %%
data_list = MIL
data_list
# Out:
# [[['H-29737', 'SPI-NJ221261-V5', 'V5', 'RV'],
#   ['H-29737', 'SPI-NJ221261-V5', 'V5', 'TLC'],
#   ['H-19899', 'SPI-NJ220058-V5', 'V5', 'RV'],
#   ['H-19899', 'SPI-NJ220058-V5', 'V5', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V1', 'V1', 'RV'],
#   ['H-19057', 'SPI-UT173336-V5', 'V5', 'RV'],
#   ['H-19057', 'SPI-UT173336-V2', 'V2', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V5', 'V5', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V2', 'V2', 'RV'],
#   ['H-19057', 'SPI-UT173336-V1', 'V1', 'TLC'],
#   ['H-19012', 'SPI-CU300039-V1', 'V1', 'TLC'],
#   ['H-19012', 'SPI-CU300039-V1', 'V1', 'RV'],
#   ['H-19000', 'SPI-WF125503-V5', 'V5', 'RV'],
#   ['H-19000', 'SPI-WF125503-V1', 'V1', 'RV'],
#   ['H-19000', 'SPI-WF125503-V5', 'V5', 'TLC'],
#   ['H-19000', 'SPI-WF125503-V1', 'V1', 'TLC'],
#   ['H-18999', 'SPI-SF184060-V1', 'V1', 'TLC'],
#   ['H-18999', 'SPI-SF184060-V1', 'V1', 'RV'],
#   ['H-18989', 'SPI-UT174912-V1', 'V1', 'RV'],
#   ['H-18989', 'SPI-UT174912-V1', 'V1', 'TLC'],
#   ['H-18988', 'SPI-UT174904-V1', 'V1', 'RV'],
#   ['H-18988', 'SPI-UT174904-V1', 'V1', 'TLC'],
#   ['H-18986', 'SPI-WF125462-V1', 'V1', 'TLC'],
#   ['H-18986', 'SPI-WF125462-V1', 'V1', 'RV'],
#   ['H-18985', 'SPI-WF125485-V1', 'V1', 'TLC'],
#   ['H-18985', 'SPI-WF125485-V1', 'V1', 'RV'],
#   ['H-18984', 'SPI-WF125473-V1', 'V1', 'RV'],
#   ['H-18984', 'SPI-WF125473-V1', 'V1', 'TLC'],
#   ['H-18983', 'SPI-WF125457-V1', 'V1', 'TLC'],
#   ['H-18983', 'SPI-WF125457-V1', 'V1', 'RV'],
#   ['H-18981', 'SPI-SF184059-V5', 'V5', 'TLC'],
#   ['H-18981', 'SPI-SF184059-V1', 'V1', 'RV'],
#   ['H-18981', 'SPI-SF184059-V5', 'V5', 'RV'],
#   ['H-18981', 'SPI-SF184059-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18979', 'SPI-WF125441-V1', 'V1', 'TLC'],
#   ['H-18979', 'SPI-WF125441-V1', 'V1', 'RV'],
#   ['H-18979', 'SPI-WF125441-V5', 'V5', 'RV'],
#   ['H-18979', 'SPI-WF125441-V5', 'V5', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V1', 'V1', 'RV'],
#   ['H-18976', 'SPI-WF125434-V1', 'V1', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V5', 'V5', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V5', 'V5', 'RV'],
#   ['H-18975', 'SPI-UT174893-V1', 'V1', 'TLC'],
#   ['H-18975', 'SPI-UT174893-V1', 'V1', 'RV'],
#   ['H-18975', 'SPI-UT174893-V5', 'V5', 'TLC'],
#   ['H-18975', 'SPI-UT174893-V5', 'V5', 'RV'],
#   ['H-18974', 'SPI-LA193613-V5', 'V5', 'RV'],
#   ['H-18974', 'SPI-LA193613-V1', 'V1', 'RV'],
#   ['H-18974', 'SPI-LA193613-V1', 'V1', 'TLC'],
#   ['H-18974', 'SPI-LA193613-V5', 'V5', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V1', 'V1', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V1', 'V1', 'RV'],
#   ['H-18971', 'SPI-SF184032-V5', 'V5', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V5', 'V5', 'RV'],
#   ['H-18970', 'SPI-SF184018-V1', 'V1', 'RV'],
#   ['H-18970', 'SPI-SF184018-V1', 'V1', 'TLC'],
#   ['H-18968', 'SPI-WF125429-V1', 'V1', 'RV'],
#   ['H-18968', 'SPI-WF125429-V5', 'V5', 'RV'],
#   ['H-18968', 'SPI-WF125429-V1', 'V1', 'TLC'],
#   ['H-18968', 'SPI-WF125429-V5', 'V5', 'TLC'],
#   ['H-18967', 'SPI-WF125416-V5', 'V5', 'RV'],
#   ['H-18967', 'SPI-WF125416-V5', 'V5', 'TLC'],
#   ['H-18967', 'SPI-WF125416-V1', 'V1', 'RV'],
#   ['H-18967', 'SPI-WF125416-V1', 'V1', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V1', 'V1', 'RV'],
#   ['H-18966', 'SPI-WF125392-V1', 'V1', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V5', 'V5', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V5', 'V5', 'RV'],
#   ['H-18965', 'SPI-SF184026-V5', 'V5', 'RV'],
#   ['H-18965', 'SPI-SF184026-V1', 'V1', 'RV'],
#   ['H-18965', 'SPI-SF184026-V5', 'V5', 'TLC'],
#   ['H-18965', 'SPI-SF184026-V1', 'V1', 'TLC'],
#   ['H-18964', 'SPI-UT174871-V1', 'V1', 'TLC'],
#   ['H-18964', 'SPI-UT174871-V1', 'V1', 'RV'],
#   ['H-18963', 'SPI-LA193637-V1', 'V1', 'RV'],
#   ['H-18963', 'SPI-LA193637-V1', 'V1', 'TLC'],
#   ['H-18962', 'SPI-LA193709-V1', 'V1', 'TLC'],
#   ['H-18962', 'SPI-LA193709-V5', 'V5', 'RV'],
#   ['H-18962', 'SPI-LA193709-V1', 'V1', 'RV'],
#   ['H-18962', 'SPI-LA193709-V5', 'V5', 'TLC'],
#   ['H-18961', 'SPI-LA193649-V1', 'V1', 'RV'],
#   ['H-18961', 'SPI-LA193649-V1', 'V1', 'TLC'],
#   ['H-18959', 'SPI-UA241144-V1', 'V1', 'RV'],
#   ['H-18959', 'SPI-UA241144-V1', 'V1', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V1', 'V1', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V1', 'V1', 'RV'],
#   ['H-18958', 'SPI-SF184005-V5', 'V5', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V5', 'V5', 'RV'],
#   ['H-18957', 'SPI-SF183999-V1', 'V1', 'TLC'],
#   ['H-18957', 'SPI-SF183999-V1', 'V1', 'RV'],
#   ['H-18956', 'SPI-SF183981-V1', 'V1', 'TLC'],
#   ['H-18956', 'SPI-SF183981-V1', 'V1', 'RV'],
#   ['H-18955', 'SPI-WF125408-V1', 'V1', 'RV'],
#   ['H-18955', 'SPI-WF125408-V5', 'V5', 'TLC'],
#   ['H-18955', 'SPI-WF125408-V1', 'V1', 'TLC'],
#   ['H-18955', 'SPI-WF125408-V5', 'V5', 'RV'],
#   ['H-18954', 'SPI-UT174887-V1', 'V1', 'TLC'],
#   ['H-18954', 'SPI-UT174887-V1', 'V1', 'RV'],
#   ['H-18951', 'SPI-SF183977-V1', 'V1', 'RV'],
#   ['H-18951', 'SPI-SF183977-V1', 'V1', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V5', 'V5', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V1', 'V1', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V5', 'V5', 'RV'],
#   ['H-18950', 'SPI-UA241193-V1', 'V1', 'RV'],
#   ['H-18949', 'SPI-UA241187-V1', 'V1', 'TLC'],
#   ['H-18949', 'SPI-UA241187-V1', 'V1', 'RV'],
#   ['H-18948', 'SPI-UA241171-V5', 'V5', 'RV'],
#   ['H-18948', 'SPI-UA241171-V1', 'V1', 'TLC'],
#   ['H-18948', 'SPI-UA241171-V5', 'V5', 'TLC'],
#   ['H-18948', 'SPI-UA241171-V1', 'V1', 'RV'],
#   ['H-18947', 'SPI-UA241160-V5', 'V5', 'TLC'],
#   ['H-18947', 'SPI-UA241160-V1', 'V1', 'RV'],
#   ['H-18947', 'SPI-UA241160-V5', 'V5', 'RV'],
#   ['H-18947', 'SPI-UA241160-V1', 'V1', 'TLC'],
#   ['H-18945', 'SPI-UA241159-V1', 'V1', 'RV'],
#   ['H-18945', 'SPI-UA241159-V1', 'V1', 'TLC'],
#   ['H-18944', 'SPI-UA241132-V1', 'V1', 'RV'],
#   ['H-18944', 'SPI-UA241132-V1', 'V1', 'TLC'],
#   ['H-18943', 'SPI-UA241126-V1', 'V1', 'TLC'],
#   ['H-18943', 'SPI-UA241126-V5', 'V5', 'RV'],
#   ['H-18943', 'SPI-UA241126-V1', 'V1', 'RV'],
#   ['H-18943', 'SPI-UA241126-V5', 'V5', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V5', 'V5', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V1', 'V1', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V5', 'V5', 'RV'],
#   ['H-18942', 'SPI-UA241118-V1', 'V1', 'RV'],
#   ['H-18941', 'SPI-LA193698-V1', 'V1', 'RV'],
#   ['H-18941', 'SPI-LA193698-V1', 'V1', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V1', 'V1', 'RV'],
#   ['H-18940', 'SPI-LA193654-V5', 'V5', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V1', 'V1', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V5', 'V5', 'RV'],
#   ['H-18939', 'SPI-LA193577-V1', 'V1', 'RV'],
#   ['H-18939', 'SPI-LA193577-V1', 'V1', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V5', 'V5', 'RV'],
#   ['H-18938', 'SPI-LA193676-V1', 'V1', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V5', 'V5', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V1', 'V1', 'RV'],
#   ['H-18937', 'SPI-LA193621-V1', 'V1', 'TLC'],
#   ['H-18937', 'SPI-LA193621-V1', 'V1', 'RV'],
#   ['H-18937', 'SPI-LA193621-V5', 'V5', 'RV'],
#   ['H-18937', 'SPI-LA193621-V5', 'V5', 'TLC'],
#   ['H-18936', 'SPI-LA193682-V1', 'V1', 'TLC'],
#   ['H-18936', 'SPI-LA193682-V1', 'V1', 'RV'],
#   ['H-18935', 'SPI-SF183966-V1', 'V1', 'RV'],
#   ['H-18935', 'SPI-SF183966-V1', 'V1', 'TLC'],
#   ['H-18935', 'SPI-SF183966-V5', 'V5', 'RV'],
#   ['H-18935', 'SPI-SF183966-V5', 'V5', 'TLC'],
#   ['H-18923', 'SPI-NJ221744-V1', 'V1', 'RV'],
#   ['H-18923', 'SPI-NJ221744-V1', 'V1', 'TLC'],
#   ['H-18922', 'SPI-NJ221732-V1', 'V1', 'TLC'],
#   ['H-18922', 'SPI-NJ221732-V1', 'V1', 'RV'],
#   ['H-18919', 'SPI-LA193599-V1', 'V1', 'RV'],
#   ['H-18919', 'SPI-LA193599-V5', 'V5', 'RV'],
#   ['H-18919', 'SPI-LA193599-V1', 'V1', 'TLC'],
#   ['H-18919', 'SPI-LA193599-V5', 'V5', 'TLC'],
#   ['H-18918', 'SPI-LA193566-V1', 'V1', 'TLC'],
#   ['H-18918', 'SPI-LA193566-V1', 'V1', 'RV'],
#   ['H-18917', 'SPI-LA193553-V1', 'V1', 'TLC'],
#   ['H-18917', 'SPI-LA193553-V1', 'V1', 'RV'],
#   ['H-18916', 'SPI-LA193665-V1', 'V1', 'TLC'],
#   ['H-18916', 'SPI-LA193665-V5', 'V5', 'RV'],
#   ['H-18916', 'SPI-LA193665-V1', 'V1', 'RV'],
#   ['H-18916', 'SPI-LA193665-V5', 'V5', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V5', 'V5', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V5', 'V5', 'RV'],
#   ['H-18915', 'SPI-LA193512-V1', 'V1', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V1', 'V1', 'RV'],
#   ['H-18914', 'SPI-LA193489-V1', 'V1', 'TLC'],
#   ['H-18914', 'SPI-LA193489-V5', 'V5', 'RV'],
#   ['H-18914', 'SPI-LA193489-V5', 'V5', 'TLC'],
#   ['H-18914', 'SPI-LA193489-V1', 'V1', 'RV'],
#   ['H-18913', 'SPI-UI251091-V1', 'V1', 'TLC'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'RV'],
#   ['H-18913', 'SPI-UI251091-V1', 'V1', 'RV'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'RV'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'TLC'],
#   ['H-18912', 'SPI-SF183953-V1', 'V1', 'RV'],
#   ['H-18912', 'SPI-SF183953-V1', 'V1', 'TLC'],
#   ['H-18910', 'SPI-UT174860-V1', 'V1', 'RV'],
#   ['H-18910', 'SPI-UT174860-V1', 'V1', 'TLC'],
#   ['H-18905', 'SPI-UT174826-V1', 'V1', 'RV'],
#   ['H-18905', 'SPI-UT174826-V1', 'V1', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V5', 'V5', 'RV'],
#   ['H-18894', 'SPI-NJ221718-V1', 'V1', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V5', 'V5', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'TLC'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'TLC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'FRC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'FRC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'FRC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'FRC'],
#   ['H-18869', 'SPI-UI251108-V5', 'V5', 'RV'],
#   ['H-18869', 'SPI-UI251108-V1', 'V1', 'RV'],
#   ['H-18869', 'SPI-UI251108-V5', 'V5', 'TLC'],
#   ['H-18869', 'SPI-UI251108-V1', 'V1', 'TLC'],
#   ['H-18866', 'SPI-UT174805-V1', 'V1', 'TLC'],
#   ['H-18866', 'SPI-UT174805-V1', 'V1', 'RV'],
#   ['H-18865', 'SPI-UT174729-V1', 'V1', 'RV'],
#   ['H-18865', 'SPI-UT174729-V1', 'V1', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V5', 'V5', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V1', 'V1', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V1', 'V1', 'RV'],
#   ['H-18864', 'SPI-UI251063-V5', 'V5', 'RV'],
#   ['H-18863', 'SPI-UI251042-V1', 'V1', 'TLC'],
#   ['H-18863', 'SPI-UI251042-V5', 'V5', 'TLC'],
#   ['H-18863', 'SPI-UI251042-V1', 'V1', 'RV'],
#   ['H-18863', 'SPI-UI251042-V5', 'V5', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'TLC'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'TLC'],
#   ['H-18861', 'SPI-NJ221726-V1', 'V1', 'RV'],
#   ['H-18861', 'SPI-NJ221726-V1', 'V1', 'TLC'],
#   ['H-18847', 'SPI-UI251056-V1', 'V1', 'RV'],
#   ['H-18847', 'SPI-UI251056-V1', 'V1', 'TLC'],
#   ['H-18845', 'SPI-NJ221638-V1', 'V1', 'RV'],
#   ['H-18845', 'SPI-NJ221638-V1', 'V1', 'TLC'],
#   ['H-18842', 'SPI-UT174818-V1', 'V1', 'TLC'],
#   ['H-18842', 'SPI-UT174818-V1', 'V1', 'RV'],
#   ['H-18840', 'SPI-UT174790-V1', 'V1', 'TLC'],
#   ['H-18840', 'SPI-UT174790-V1', 'V1', 'RV'],
#   ['H-18838', 'SPI-WF125294-V1', 'V1', 'RV'],
#   ['H-18838', 'SPI-WF125294-V1', 'V1', 'TLC'],
#   ['H-18837', 'SPI-UI251030-V5', 'V5', 'RV'],
#   ['H-18837', 'SPI-UI251030-V1', 'V1', 'RV'],
#   ['H-18837', 'SPI-UI251030-V5', 'V5', 'TLC'],
#   ['H-18837', 'SPI-UI251030-V1', 'V1', 'TLC'],
#   ['H-18836', 'SPI-UI251028-V1', 'V1', 'TLC'],
#   ['H-18836', 'SPI-UI251028-V1', 'V1', 'RV'],
#   ['H-18836', 'SPI-UI251028-V5', 'V5', 'RV'],
#   ['H-18836', 'SPI-UI251028-V5', 'V5', 'TLC'],
#   ['H-18835', 'SPI-SF183938-V1', 'V1', 'TLC'],
#   ['H-18835', 'SPI-SF183938-V1', 'V1', 'RV'],
#   ['H-18834', 'SPI-UA241105-V1', 'V1', 'RV'],
#   ['H-18834', 'SPI-UA241105-V1', 'V1', 'TLC'],
#   ['H-18833', 'SPI-NJ221653-V1', 'V1', 'TLC'],
#   ['H-18833', 'SPI-NJ221653-V1', 'V1', 'RV'],
#   ['H-18832', 'SPI-NJ221666-V1', 'V1', 'TLC'],
#   ['H-18832', 'SPI-NJ221666-V1', 'V1', 'RV'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'TLC'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'TLC'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'RV'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'FRC'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'FRC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18824', 'SPI-UT174785-V1', 'V1', 'RV'],
#   ['H-18824', 'SPI-UT174785-V1', 'V1', 'TLC'],
#   ['H-18823', 'SPI-UT174773-V1', 'V1', 'TLC'],
#   ['H-18823', 'SPI-UT174773-V1', 'V1', 'RV'],
#   ['H-18822', 'SPI-UT174757-V1', 'V1', 'RV'],
#   ['H-18822', 'SPI-UT174757-V1', 'V1', 'TLC'],
#   ['H-18821', 'SPI-UT174741-V1', 'V1', 'RV'],
#   ['H-18821', 'SPI-UT174741-V1', 'V1', 'TLC'],
#   ['H-18820', 'SPI-UT174734-V1', 'V1', 'RV'],
#   ['H-18820', 'SPI-UT174734-V1', 'V1', 'TLC'],
#   ['H-18819', 'SPI-UT174716-V1', 'V1', 'TLC'],
#   ['H-18819', 'SPI-UT174716-V1', 'V1', 'RV'],
#   ['H-18818', 'SPI-UI250999-V1', 'V1', 'RV'],
#   ['H-18818', 'SPI-UI250999-V5', 'V5', 'TLC'],
#   ['H-18818', 'SPI-UI250999-V1', 'V1', 'TLC'],
#   ['H-18818', 'SPI-UI250999-V5', 'V5', 'RV'],
#   ['H-18817', 'SPI-UI250953-V1', 'V1', 'RV'],
#   ['H-18817', 'SPI-UI250953-V1', 'V1', 'TLC'],
#   ['H-18816', 'SPI-UI250966-V1', 'V1', 'TLC'],
#   ['H-18816', 'SPI-UI250966-V1', 'V1', 'RV'],
#   ['H-18815', 'SPI-UI250981-V5', 'V5', 'TLC'],
#   ['H-18815', 'SPI-UI250981-V5', 'V5', 'RV'],
#   ['H-18815', 'SPI-UI250981-V1', 'V1', 'RV'],
#   ['H-18815', 'SPI-UI250981-V1', 'V1', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V1', 'V1', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V5', 'V5', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V1', 'V1', 'RV'],
#   ['H-18814', 'SPI-UI250977-V5', 'V5', 'RV'],
#   ['H-18813', 'SPI-WF125370-V1', 'V1', 'RV'],
#   ['H-18813', 'SPI-WF125370-V1', 'V1', 'TLC'],
#   ['H-18812', 'SPI-WF125355-V1', 'V1', 'TLC'],
#   ['H-18812', 'SPI-WF125355-V1', 'V1', 'RV'],
#   ['H-18811', 'SPI-NJ221620-V1', 'V1', 'RV'],
#   ['H-18811', 'SPI-NJ221620-V1', 'V1', 'TLC'],
#   ['H-18810', 'SPI-NJ221595-V1', 'V1', 'TLC'],
#   ['H-18810', 'SPI-NJ221595-V5', 'V5', 'RV'],
#   ['H-18810', 'SPI-NJ221595-V1', 'V1', 'RV'],
#   ['H-18810', 'SPI-NJ221595-V5', 'V5', 'TLC'],
#   ['H-18809', 'SPI-NJ221567-V1', 'V1', 'RV'],
#   ['H-18809', 'SPI-NJ221567-V1', 'V1', 'TLC'],
#   ['H-18750', 'SPI-LA303692-V1', 'V1', 'RV'],
#   ['H-18750', 'SPI-LA303692-V1', 'V1', 'TLC'],
#   ['H-18749', 'SPI-LA193442-V1', 'V1', 'RV'],
#   ['H-18749', 'SPI-LA193442-V1', 'V1', 'TLC'],
#   ['H-18748', 'SPI-SF183920-V2', 'V2', 'RV'],
#   ['H-18748', 'SPI-SF183920-V1', 'V1', 'TLC'],
#   ['H-18748', 'SPI-SF183920-V1', 'V1', 'RV'],
#   ['H-18748', 'SPI-SF183920-V2', 'V2', 'TLC'],
#   ['H-18747', 'SPI-UA241094-V1', 'V1', 'TLC'],
#   ['H-18747', 'SPI-UA241094-V1', 'V1', 'RV'],
#   ['H-18745', 'SPI-UI250920-V1', 'V1', 'RV'],
#   ['H-18745', 'SPI-UI250920-V1', 'V1', 'TLC'],
#   ['H-18745', 'SPI-UI250920-V5', 'V5', 'RV'],
#   ['H-18745', 'SPI-UI250920-V5', 'V5', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V1', 'V1', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V5', 'V5', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V1', 'V1', 'RV'],
#   ['H-18744', 'SPI-UA241086-V5', 'V5', 'RV'],
#   ['H-18743', 'SPI-NJ221511-V1', 'V1', 'TLC'],
#   ['H-18743', 'SPI-NJ221511-V1', 'V1', 'RV'],
#   ['H-18742', 'SPI-NJ221677-V1', 'V1', 'TLC'],
#   ['H-18742', 'SPI-NJ221677-V1', 'V1', 'RV'],
#   ['H-18741', 'SPI-NJ221699-V1', 'V1', 'TLC'],
#   ['H-18741', 'SPI-NJ221699-V1', 'V1', 'RV'],
#   ['H-18740', 'SPI-NJ221552-V1', 'V1', 'TLC'],
#   ['H-18740', 'SPI-NJ221552-V1', 'V1', 'RV'],
#   ['H-18729', 'SPI-NJ220379-V5', 'V5', 'TLC'],
#   ['H-18729', 'SPI-NJ220379-V2', 'V2', 'TLC'],
#   ['H-18729', 'SPI-NJ220379-V5', 'V5', 'RV'],
#   ['H-18729', 'SPI-NJ220379-V2', 'V2', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V1', 'V1', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V5', 'V5', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V5', 'V5', 'TLC'],
#   ['H-18728', 'SPI-NJ221580-V1', 'V1', 'TLC'],
#   ['H-18727', 'SPI-WF125343-V1', 'V1', 'TLC'],
#   ['H-18727', 'SPI-WF125343-V1', 'V1', 'RV'],
#   ['H-18726', 'SPI-SF183912-V1', 'V1', 'RV'],
#   ['H-18726', 'SPI-SF183912-V1', 'V1', 'TLC'],
#   ['H-18726', 'SPI-SF183912-V2', 'V2', 'TLC'],
#   ['H-18726', 'SPI-SF183912-V2', 'V2', 'RV'],
#   ['H-18725', 'SPI-SF183904-V1', 'V1', 'RV'],
#   ['H-18725', 'SPI-SF183904-V1', 'V1', 'TLC'],
#   ['H-18724', 'SPI-SF183844-V1', 'V1', 'RV'],
#   ['H-18724', 'SPI-SF183844-V2', 'V2', 'RV'],
#   ['H-18724', 'SPI-SF183844-V1', 'V1', 'TLC'],
#   ['H-18724', 'SPI-SF183844-V2', 'V2', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V5', 'V5', 'RV'],
#   ['H-18723', 'SPI-SF183893-V1', 'V1', 'RV'],
#   ['H-18723', 'SPI-SF183893-V5', 'V5', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V1', 'V1', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V2', 'V2', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V2', 'V2', 'RV'],
#   ['H-18722', 'SPI-SF183860-V1', 'V1', 'RV'],
#   ['H-18722', 'SPI-SF183860-V1', 'V1', 'TLC'],
#   ['H-18722', 'SPI-SF183860-V5', 'V5', 'TLC'],
#   ['H-18722', 'SPI-SF183860-V5', 'V5', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'TLC'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V1', 'V1', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V1', 'V1', 'RV'],
#   ['H-18720', 'SPI-LA193456-V5', 'V5', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V5', 'V5', 'RV'],
#   ['H-18719', 'SPI-LA303688-V1', 'V1', 'RV'],
#   ['H-18719', 'SPI-LA303688-V1', 'V1', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V1', 'V1', 'RV'],
#   ['H-18718', 'SPI-LA193430-V1', 'V1', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V5', 'V5', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V5', 'V5', 'RV'],
#   ['H-18717', 'SPI-LA193371-V1', 'V1', 'RV'],
#   ['H-18717', 'SPI-LA193371-V1', 'V1', 'TLC'],
#   ['H-18716', 'SPI-UA241072-V1', 'V1', 'TLC'],
#   ['H-18716', 'SPI-UA241072-V1', 'V1', 'RV'],
#   ['H-18712', 'SPI-UI250945-V5', 'V5', 'RV'],
#   ['H-18712', 'SPI-UI250945-V1', 'V1', 'TLC'],
#   ['H-18712', 'SPI-UI250945-V5', 'V5', 'TLC'],
#   ['H-18712', 'SPI-UI250945-V1', 'V1', 'RV'],
#   ['H-18711', 'SPI-UA241061-V5', 'V5', 'TLC'],
#   ['H-18711', 'SPI-UA241061-V1', 'V1', 'TLC'],
#   ['H-18711', 'SPI-UA241061-V5', 'V5', 'RV'],
#   ['H-18711', 'SPI-UA241061-V1', 'V1', 'RV'],
#   ['H-18710', 'SPI-UA241040-V5', 'V5', 'TLC'],
#   ['H-18710', 'SPI-UA241040-V1', 'V1', 'RV'],
#   ['H-18710', 'SPI-UA241040-V5', 'V5', 'RV'],
#   ['H-18710', 'SPI-UA241040-V1', 'V1', 'TLC'],
#   ['H-18709', 'SPI-UA241033-V1', 'V1', 'TLC'],
#   ['H-18709', 'SPI-UA241033-V1', 'V1', 'RV'],
#   ['H-18708', 'SPI-WF125331-V1', 'V1', 'TLC'],
#   ['H-18708', 'SPI-WF125331-V1', 'V1', 'RV'],
#   ['H-18707', 'SPI-WF125327-V1', 'V1', 'TLC'],
#   ['H-18707', 'SPI-WF125327-V1', 'V1', 'RV'],
#   ['H-18707', 'SPI-WF125327-V5', 'V5', 'RV'],
#   ['H-18707', 'SPI-WF125327-V5', 'V5', 'TLC'],
#   ['H-18705', 'SPI-UA241058-V1', 'V1', 'TLC'],
#   ['H-18705', 'SPI-UA241058-V1', 'V1', 'RV'],
#   ['H-18704', 'SPI-UA241025-V5', 'V5', 'TLC'],
#   ['H-18704', 'SPI-UA241025-V5', 'V5', 'RV'],
#   ['H-18704', 'SPI-UA241025-V1', 'V1', 'RV'],
#   ['H-18704', 'SPI-UA241025-V1', 'V1', 'TLC'],
#   ['H-18703', 'SPI-UA241017-V1', 'V1', 'TLC'],
#   ['H-18703', 'SPI-UA241017-V1', 'V1', 'RV'],
#   ['H-18702', 'SPI-UA241009-V1', 'V1', 'TLC'],
#   ['H-18702', 'SPI-UA241009-V5', 'V5', 'TLC'],
#   ['H-18702', 'SPI-UA241009-V1', 'V1', 'RV'],
#   ['H-18702', 'SPI-UA241009-V5', 'V5', 'RV'],
#   ['H-18701', 'SPI-UA240996-V2', 'V2', 'TLC'],
#   ['H-18701', 'SPI-UA240996-V1', 'V1', 'RV'],
#   ['H-18701', 'SPI-UA240996-V2', 'V2', 'RV'],
#   ['H-18701', 'SPI-UA240996-V5', 'V5', 'RV'],
#   ['H-18701', 'SPI-UA240996-V1', 'V1', 'TLC'],
#   ['H-18701', 'SPI-UA240996-V5', 'V5', 'TLC'],
#   ['H-18700', 'SPI-UT174697-V1', 'V1', 'RV'],
#   ['H-18700', 'SPI-UT174697-V1', 'V1', 'TLC'],
#   ['H-18699', 'SPI-UT174683-V1', 'V1', 'RV'],
#   ['H-18699', 'SPI-UT174683-V1', 'V1', 'TLC'],
#   ['H-18687', 'SPI-UI250912-V1', 'V1', 'TLC'],
#   ['H-18687', 'SPI-UI250912-V1', 'V1', 'RV'],
#   ['H-18687', 'SPI-UI250912-V5', 'V5', 'RV'],
#   ['H-18687', 'SPI-UI250912-V5', 'V5', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V2', 'V2', 'RV'],
#   ['H-18686', 'SPI-SF183887-V5', 'V5', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V2', 'V2', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V5', 'V5', 'RV'],
#   ['H-18686', 'SPI-SF183887-V1', 'V1', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V1', 'V1', 'RV'],
#   ['H-18685', 'SPI-SF183871-V1', 'V1', 'TLC'],
#   ['H-18685', 'SPI-SF183871-V5', 'V5', 'TLC'],
#   ['H-18685', 'SPI-SF183871-V1', 'V1', 'RV'],
#   ['H-18685', 'SPI-SF183871-V5', 'V5', 'RV'],
#   ['H-18684', 'SPI-UI250893-V1', 'V1', 'RV'],
#   ['H-18684', 'SPI-UI250893-V1', 'V1', 'TLC'],
#   ['H-18683', 'SPI-UI250887-V5', 'V5', 'RV'],
#   ['H-18683', 'SPI-UI250887-V1', 'V1', 'RV'],
#   ['H-18683', 'SPI-UI250887-V5', 'V5', 'TLC'],
#   ['H-18683', 'SPI-UI250887-V1', 'V1', 'TLC'],
#   ['H-18682', 'SPI-UI250826-V1', 'V1', 'TLC'],
#   ['H-18682', 'SPI-UI250826-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18679', 'SPI-JH300602-V1', 'V1', 'RV'],
#   ['H-18679', 'SPI-JH300602-V1', 'V1', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V1', 'V1', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V5', 'V5', 'RV'],
#   ['H-18678', 'SPI-UT174675-V1', 'V1', 'RV'],
#   ['H-18678', 'SPI-UT174675-V2', 'V2', 'RV'],
#   ['H-18678', 'SPI-UT174675-V2', 'V2', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V5', 'V5', 'TLC'],
#   ['H-18677', 'SPI-UI250860-V1', 'V1', 'RV'],
#   ['H-18677', 'SPI-UI250860-V1', 'V1', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V1', 'V1', 'RV'],
#   ['H-18676', 'SPI-UT174650-V2', 'V2', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V1', 'V1', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V2', 'V2', 'RV'],
#   ['H-18673', 'SPI-UI250762-V1', 'V1', 'TLC'],
#   ['H-18673', 'SPI-UI250762-V1', 'V1', 'RV'],
#   ['H-18673', 'SPI-UI250762-V5', 'V5', 'RV'],
#   ['H-18673', 'SPI-UI250762-V5', 'V5', 'TLC'],
#   ['H-18672', 'SPI-NJ221473-V1', 'V1', 'TLC'],
#   ['H-18672', 'SPI-NJ221473-V1', 'V1', 'RV'],
#   ['H-18672', 'SPI-NJ221473-V5', 'V5', 'RV'],
#   ['H-18672', 'SPI-NJ221473-V5', 'V5', 'TLC'],
#   ['H-18666', 'SPI-LA193360-V1', 'V1', 'RV'],
#   ['H-18666', 'SPI-LA193360-V1', 'V1', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V1', 'V1', 'RV'],
#   ['H-18662', 'SPI-LA192862-V1', 'V1', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V2', 'V2', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V2', 'V2', 'RV'],
#   ['H-18661', 'SPI-WF125272-V5', 'V5', 'RV'],
#   ['H-18661', 'SPI-WF125272-V1', 'V1', 'TLC'],
#   ['H-18661', 'SPI-WF125272-V5', 'V5', 'TLC'],
#   ['H-18661', 'SPI-WF125272-V1', 'V1', 'RV'],
#   ['H-18660', 'SPI-UI250818-V5', 'V5', 'TLC'],
#   ['H-18660', 'SPI-UI250818-V1', 'V1', 'RV'],
#   ['H-18660', 'SPI-UI250818-V5', 'V5', 'RV'],
#   ['H-18660', 'SPI-UI250818-V1', 'V1', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V2', 'V2', 'RV'],
#   ['H-18656', 'SPI-LA193387-V1', 'V1', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V2', 'V2', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V1', 'V1', 'RV'],
#   ['H-18656', 'SPI-LA193387-V5', 'V5', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V5', 'V5', 'RV'],
#   ['H-18643', 'SPI-NJ221485-V1', 'V1', 'RV'],
#   ['H-18643', 'SPI-NJ221485-V1', 'V1', 'TLC'],
#   ['H-18642', 'SPI-NJ221355-V1', 'V1', 'RV'],
#   ['H-18642', 'SPI-NJ221355-V1', 'V1', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V5', 'V5', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V1', 'V1', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V5', 'V5', 'RV'],
#   ['H-18641', 'SPI-WF125319-V1', 'V1', 'RV'],
#   ['H-18640', 'SPI-WF125286-V1', 'V1', 'TLC'],
#   ['H-18640', 'SPI-WF125286-V1', 'V1', 'RV'],
#   ['H-18637', 'SPI-UA240984-V1', 'V1', 'TLC'],
#   ['H-18637', 'SPI-UA240984-V5', 'V5', 'TLC'],
#   ['H-18637', 'SPI-UA240984-V1', 'V1', 'RV'],
#   ['H-18637', 'SPI-UA240984-V5', 'V5', 'RV'],
#   ['H-18634', 'SPI-UA240979-V1', 'V1', 'RV'],
#   ['H-18634', 'SPI-UA240979-V1', 'V1', 'TLC'],
#   ['H-18633', 'SPI-UT174669-V1', 'V1', 'RV'],
#   ['H-18633', 'SPI-UT174669-V1', 'V1', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V5', 'V5', 'RV'],
#   ['H-18632', 'SPI-UI250785-V1', 'V1', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V5', 'V5', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V1', 'V1', 'RV'],
#   ['H-18631', 'SPI-SF183859-V1', 'V1', 'TLC'],
#   ['H-18631', 'SPI-SF183859-V1', 'V1', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V1', 'V1', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V1', 'V1', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-LNC', 'LNC', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-LNC', 'LNC', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'FRC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18629', 'SPI-JH112386-V1', 'V1', 'TLC'],
#   ['H-18629', 'SPI-JH112386-V1', 'V1', 'RV'],
#   ['H-18626', 'SPI-UA240807-V5', 'V5', 'TLC'],
#   ['H-18626', 'SPI-UA240807-V1', 'V1', 'RV'],
#   ['H-18626', 'SPI-UA240807-V5', 'V5', 'RV'],
#   ['H-18626', 'SPI-UA240807-V2', 'V2', 'RV'],
#   ['H-18626', 'SPI-UA240807-V1', 'V1', 'TLC'],
#   ['H-18626', 'SPI-UA240807-V2', 'V2', 'TLC'],
#   ['H-18623', 'SPI-JH115631-V1', 'V1', 'TLC'],
#   ['H-18623', 'SPI-JH115631-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'TLC'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'FRC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'TLC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'FRC'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18598', 'SPI-WF125233-V1', 'V1', 'RV'],
#   ['H-18598', 'SPI-WF125233-V1', 'V1', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V5', 'V5', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V1', 'V1', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V5', 'V5', 'RV'],
#   ['H-18596', 'SPI-SF183826-V1', 'V1', 'RV'],
#   ['H-18595', 'SPI-UA240968-V1', 'V1', 'TLC'],
#   ['H-18595', 'SPI-UA240968-V1', 'V1', 'RV'],
#   ['H-18594', 'SPI-WF125240-V1', 'V1', 'RV'],
#   ['H-18594', 'SPI-WF125240-V5', 'V5', 'TLC'],
#   ['H-18594', 'SPI-WF125240-V1', 'V1', 'TLC'],
#   ['H-18594', 'SPI-WF125240-V5', 'V5', 'RV'],
#   ['H-18593', 'SPI-UI250757-V1', 'V1', 'TLC'],
#   ['H-18593', 'SPI-UI250757-V1', 'V1', 'RV'],
#   ['H-18593', 'SPI-UI250757-V5', 'V5', 'RV'],
#   ['H-18593', 'SPI-UI250757-V5', 'V5', 'TLC'],
#   ['H-18592', 'SPI-UI250675-V1', 'V1', 'RV'],
#   ['H-18592', 'SPI-UI250675-V1', 'V1', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V5', 'V5', 'RV'],
#   ['H-18591', 'SPI-UI250741-V5', 'V5', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V1', 'V1', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V1', 'V1', 'RV'],
#   ['H-18586', 'SPI-JH112464-V1', 'V1', 'TLC'],
#   ['H-18586', 'SPI-JH112464-V1', 'V1', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V1', 'V1', 'TLC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V1', 'V1', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'FRC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'TLC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-LNC', 'LNC', 'TLC'],
#   ['H-18585', 'SPI-JH112455-LNC', 'LNC', 'RV'],
#   ['H-18584', 'SPI-JH112443-V1', 'V1', 'RV'],
#   ['H-18584', 'SPI-JH112443-V1', 'V1', 'TLC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'FRC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'TLC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'RV'],
#   ['H-18581', 'SPI-SF183818-V1', 'V1', 'TLC'],
#   ['H-18581', 'SPI-SF183818-V1', 'V1', 'RV'],
#   ['H-18581', 'SPI-SF183818-V5', 'V5', 'TLC'],
#   ['H-18581', 'SPI-SF183818-V5', 'V5', 'RV'],
#   ['H-18580', 'SPI-UI250716-V1', 'V1', 'TLC'],
#   ['H-18580', 'SPI-UI250716-V1', 'V1', 'RV'],
#   ['H-18580', 'SPI-UI250716-V5', 'V5', 'RV'],
#   ['H-18580', 'SPI-UI250716-V5', 'V5', 'TLC'],
#   ['H-18579', 'SPI-NJ221183-V1', 'V1', 'RV'],
#   ['H-18579', 'SPI-NJ221183-V5', 'V5', 'RV'],
#   ['H-18579', 'SPI-NJ221183-V1', 'V1', 'TLC'],
#   ['H-18579', 'SPI-NJ221183-V5', 'V5', 'TLC'],
#   ['H-18578', 'SPI-NJ221434-V1', 'V1', 'TLC'],
#   ['H-18578', 'SPI-NJ221434-V1', 'V1', 'RV'],
#   ['H-18577', 'SPI-NJ221441-V1', 'V1', 'TLC'],
#   ['H-18577', 'SPI-NJ221441-V1', 'V1', 'RV'],
#   ['H-18576', 'SPI-UI250729-V1', 'V1', 'RV'],
#   ['H-18576', 'SPI-UI250729-V1', 'V1', 'TLC'],
#   ['H-18576', 'SPI-UI250729-V5', 'V5', 'RV'],
#   ['H-18576', 'SPI-UI250729-V5', 'V5', 'TLC'],
#   ['H-18575', 'SPI-SF183785-V1', 'V1', 'RV'],
#   ['H-18575', 'SPI-SF183785-V5', 'V5', 'RV'],
#   ['H-18575', 'SPI-SF183785-V1', 'V1', 'TLC'],
#   ['H-18575', 'SPI-SF183785-V5', 'V5', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V2', 'V2', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V1', 'V1', 'RV'],
#   ['H-18574', 'SPI-UA240951-V2', 'V2', 'RV'],
#   ['H-18574', 'SPI-UA240951-V1', 'V1', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V5', 'V5', 'RV'],
#   ['H-18574', 'SPI-UA240951-V5', 'V5', 'TLC'],
#   ['H-18573', 'SPI-WF125150-V1', 'V1', 'RV'],
#   ['H-18573', 'SPI-WF125150-V1', 'V1', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V1', 'V1', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V1', 'V1', 'RV'],
#   ['H-18572', 'SPI-UT174648-V2', 'V2', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V2', 'V2', 'RV'],
#   ['H-18571', 'SPI-JH112419-V1', 'V1', 'RV'],
#   ['H-18571', 'SPI-JH112419-V1', 'V1', 'TLC'],
#   ['H-18570', 'SPI-JH112333-V1', 'V1', 'RV'],
#   ['H-18570', 'SPI-JH112333-V1', 'V1', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V1', 'V1', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V1', 'V1', 'RV'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'RV'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'FRC'],
#   ['H-18555', 'SPI-UA240947-V1', 'V1', 'TLC'],
#   ['H-18555', 'SPI-UA240947-V1', 'V1', 'RV'],
#   ['H-18554', 'SPI-UA240910-V1', 'V1', 'RV'],
#   ['H-18554', 'SPI-UA240910-V2', 'V2', 'TLC'],
#   ['H-18554', 'SPI-UA240910-V1', 'V1', 'TLC'],
#   ['H-18554', 'SPI-UA240910-V2', 'V2', 'RV'],
#   ['H-18552', 'SPI-JH112361-V2', 'V2', 'RV'],
#   ['H-18552', 'SPI-JH112361-V1', 'V1', 'RV'],
#   ['H-18552', 'SPI-JH112361-V2', 'V2', 'TLC'],
#   ['H-18552', 'SPI-JH112361-V1', 'V1', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'FRC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V1', 'V1', 'TLC'],
#   ['H-18551', 'SPI-JH112358-V1', 'V1', 'RV'],
#   ['H-18551', 'SPI-JH112358-V2', 'V2', 'RV'],
#   ['H-18551', 'SPI-JH112358-V2', 'V2', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-LNC', 'LNC', 'RV'],
#   ['H-18551', 'SPI-JH112358-LNC', 'LNC', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18550', 'SPI-JH115670-V2', 'V2', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V1', 'V1', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V2', 'V2', 'RV'],
#   ['H-18550', 'SPI-JH115670-V1', 'V1', 'RV'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'RV'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'FRC'],
#   ['H-18549', 'SPI-JH300583-V1', 'V1', 'TLC'],
#   ['H-18549', 'SPI-JH300583-V1', 'V1', 'RV'],
#   ['H-18548', 'SPI-JH112317-V1', 'V1', 'RV'],
#   ['H-18548', 'SPI-JH112317-V1', 'V1', 'TLC'],
#   ['H-18547', 'SPI-JH112207-V1', 'V1', 'RV'],
#   ['H-18547', 'SPI-JH112207-V1', 'V1', 'TLC'],
#   ['H-18545', 'SPI-LA193344-V1', 'V1', 'TLC'],
#   ['H-18545', 'SPI-LA193344-V1', 'V1', 'RV'],
#   ['H-18516', 'SPI-MU164732-V1', 'V1', 'TLC'],
#   ['H-18516', 'SPI-MU164732-V1', 'V1', 'RV'],
#   ['H-18516', 'SPI-MU164732-V5', 'V5', 'TLC'],
#   ['H-18516', 'SPI-MU164732-V5', 'V5', 'RV'],
#   ['H-18515', 'SPI-MU164718-V1', 'V1', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V1', 'V1', 'RV'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'RV'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'RV'],
#   ['H-18514', 'SPI-MU164726-V1', 'V1', 'TLC'],
#   ['H-18514', 'SPI-MU164726-V1', 'V1', 'RV'],
#   ['H-18514', 'SPI-MU164726-V5', 'V5', 'TLC'],
#   ['H-18514', 'SPI-MU164726-V5', 'V5', 'RV'],
#   ['H-18513', 'SPI-JH112289-V1', 'V1', 'TLC'],
#   ['H-18513', 'SPI-JH112289-V1', 'V1', 'RV'],
#   ['H-18512', 'SPI-JH112325-V1', 'V1', 'TLC'],
#   ['H-18512', 'SPI-JH112325-V1', 'V1', 'RV'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'TLC'],
#   ['H-18511', 'SPI-JH112291-V1', 'V1', 'TLC'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'RV'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'FRC'],
#   ['H-18511', 'SPI-JH112291-V1', 'V1', 'RV'],
#   ['H-18510', 'SPI-JH112195-V1', 'V1', 'RV'],
#   ['H-18510', 'SPI-JH112195-V1', 'V1', 'TLC'],
#   ['H-18509', 'SPI-JH115917-V1', 'V1', 'TLC'],
#   ['H-18509', 'SPI-JH115917-V1', 'V1', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V5', 'V5', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V1', 'V1', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V5', 'V5', 'TLC'],
#   ['H-18508', 'SPI-NJ221429-V1', 'V1', 'TLC'],
#   ['H-18507', 'SPI-NJ221416-V5', 'V5', 'RV'],
#   ['H-18507', 'SPI-NJ221416-V5', 'V5', 'TLC'],
#   ['H-18507', 'SPI-NJ221416-V1', 'V1', 'RV'],
#   ['H-18507', 'SPI-NJ221416-V1', 'V1', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V5', 'V5', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V1', 'V1', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V5', 'V5', 'RV'],
#   ['H-18506', 'SPI-NJ221364-V1', 'V1', 'RV'],
#   ['H-18505', 'SPI-NJ221225-V1', 'V1', 'RV'],
#   ['H-18505', 'SPI-NJ221225-V1', 'V1', 'TLC'],
#   ['H-18504', 'SPI-NJ221370-V1', 'V1', 'RV'],
#   ['H-18504', 'SPI-NJ221370-V1', 'V1', 'TLC'],
#   ['H-18503', 'SPI-NJ221294-V1', 'V1', 'TLC'],
#   ['H-18503', 'SPI-NJ221294-V1', 'V1', 'RV'],
#   ['H-18502', 'SPI-UT174636-V1', 'V1', 'TLC'],
#   ['H-18502', 'SPI-UT174636-V1', 'V1', 'RV'],
#   ['H-18502', 'SPI-UT174636-V2', 'V2', 'RV'],
#   ['H-18502', 'SPI-UT174636-V2', 'V2', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V2', 'V2', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V1', 'V1', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V2', 'V2', 'RV'],
#   ['H-18501', 'SPI-UT174601-V1', 'V1', 'RV'],
#   ['H-18500', 'SPI-UT174598-V1', 'V1', 'TLC'],
#   ['H-18500', 'SPI-UT174598-V1', 'V1', 'RV'],
#   ['H-18500', 'SPI-UT174598-V2', 'V2', 'TLC'],
#   ['H-18500', 'SPI-UT174598-V2', 'V2', 'RV'],
#   ['H-18499', 'SPI-SF183805-V1', 'V1', 'RV'],
#   ['H-18499', 'SPI-SF183805-V2', 'V2', 'TLC'],
#   ['H-18499', 'SPI-SF183805-V1', 'V1', 'TLC'],
#   ['H-18499', 'SPI-SF183805-V2', 'V2', 'RV'],
#   ['H-18498', 'SPI-SF183790-V1', 'V1', 'RV'],
#   ['H-18498', 'SPI-SF183790-V2', 'V2', 'TLC'],
#   ['H-18498', 'SPI-SF183790-V1', 'V1', 'TLC'],
#   ['H-18498', 'SPI-SF183790-V5', 'V5', 'RV'],
#   ['H-18498', 'SPI-SF183790-V2', 'V2', 'RV'],
#   ['H-18498', 'SPI-SF183790-V5', 'V5', 'TLC'],
#   ['H-18497', 'SPI-WF125217-V1', 'V1', 'TLC'],
#   ['H-18497', 'SPI-WF125217-V1', 'V1', 'RV'],
#   ['H-18496', 'SPI-WF125209-V1', 'V1', 'TLC'],
#   ['H-18496', 'SPI-WF125209-V2', 'V2', 'TLC'],
#   ['H-18496', 'SPI-WF125209-V1', 'V1', 'RV'],
#   ['H-18496', 'SPI-WF125209-V2', 'V2', 'RV'],
#   ['H-18496', 'SPI-WF125209-V5', 'V5', 'RV'],
#   ['H-18496', 'SPI-WF125209-V5', 'V5', 'TLC'],
#   ['H-18495', 'SPI-WF125197-V1', 'V1', 'RV'],
#   ['H-18495', 'SPI-WF125197-V5', 'V5', 'RV'],
#   ['H-18495', 'SPI-WF125197-V1', 'V1', 'TLC'],
#   ['H-18495', 'SPI-WF125197-V5', 'V5', 'TLC'],
#   ['H-18494', 'SPI-WF125148-V1', 'V1', 'RV'],
#   ['H-18494', 'SPI-WF125148-V1', 'V1', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V1', 'V1', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V1', 'V1', 'RV'],
#   ['H-18493', 'SPI-WF124740-V2', 'V2', 'RV'],
#   ['H-18493', 'SPI-WF124740-V2', 'V2', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V5', 'V5', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V5', 'V5', 'RV'],
#   ['H-18492', 'SPI-WF125183-V5', 'V5', 'TLC'],
#   ['H-18492', 'SPI-WF125183-V1', 'V1', 'TLC'],
#   ['H-18492', 'SPI-WF125183-V5', 'V5', 'RV'],
#   ['H-18492', 'SPI-WF125183-V1', 'V1', 'RV'],
#   ['H-18491', 'SPI-UA240935-V1', 'V1', 'TLC'],
#   ['H-18491', 'SPI-UA240935-V1', 'V1', 'RV'],
#   ['H-18491', 'SPI-UA240935-V2', 'V2', 'RV'],
#   ['H-18491', 'SPI-UA240935-V2', 'V2', 'TLC'],
#   ['H-18490', 'SPI-UA240923-V1', 'V1', 'TLC'],
#   ['H-18490', 'SPI-UA240923-V1', 'V1', 'RV'],
#   ['H-18489', 'SPI-UA240902-V2', 'V2', 'RV'],
#   ['H-18489', 'SPI-UA240902-V1', 'V1', 'TLC'],
#   ['H-18489', 'SPI-UA240902-V2', 'V2', 'TLC'],
#   ['H-18489', 'SPI-UA240902-V5', 'V5', 'RV'],
#   ['H-18489', 'SPI-UA240902-V1', 'V1', 'RV'],
#   ['H-18489', 'SPI-UA240902-V5', 'V5', 'TLC'],
#   ['H-18488', 'SPI-UI250708-V1', 'V1', 'TLC'],
#   ['H-18488', 'SPI-UI250708-V1', 'V1', 'RV'],
#   ['H-18487', 'SPI-UI250697-V1', 'V1', 'RV'],
#   ['H-18487', 'SPI-UI250697-V2', 'V2', 'TLC'],
#   ['H-18487', 'SPI-UI250697-V2', 'V2', 'RV'],
#   ['H-18487', 'SPI-UI250697-V1', 'V1', 'TLC'],
#   ['H-18486', 'SPI-UI250683-V1', 'V1', 'TLC'],
#   ['H-18486', 'SPI-UI250683-V1', 'V1', 'RV'],
#   ['H-18485', 'SPI-UI250669-V1', 'V1', 'TLC'],
#   ['H-18485', 'SPI-UI250669-V2', 'V2', 'TLC'],
#   ['H-18485', 'SPI-UI250669-V1', 'V1', 'RV'],
#   ['H-18485', 'SPI-UI250669-V2', 'V2', 'RV'],
#   ['H-18484', 'SPI-UI250648-V1', 'V1', 'TLC'],
#   ['H-18484', 'SPI-UI250648-V1', 'V1', 'RV'],
#   ['H-18483', 'SPI-UI250622-V1', 'V1', 'TLC'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'TLC'],
#   ['H-18483', 'SPI-UI250622-V1', 'V1', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V1', 'V1', 'RV'],
#   ['H-18482', 'SPI-UI250636-V2', 'V2', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V1', 'V1', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V2', 'V2', 'RV'],
#   ['H-18482', 'SPI-UI250636-V5', 'V5', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V5', 'V5', 'RV'],
#   ['H-18481', 'SPI-CU105112-V1', 'V1', 'RV'],
#   ['H-18481', 'SPI-CU105112-V5', 'V5', 'RV'],
#   ['H-18481', 'SPI-CU105112-V2', 'V2', 'TLC'],
#   ['H-18481', 'SPI-CU105112-V1', 'V1', 'TLC'],
#   ['H-18481', 'SPI-CU105112-V2', 'V2', 'RV'],
#   ['H-18481', 'SPI-CU105112-V5', 'V5', 'TLC'],
#   ['H-18480', 'SPI-CU105104-V1', 'V1', 'RV'],
#   ['H-18480', 'SPI-CU105104-V1', 'V1', 'TLC'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'TLC'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'RV'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'RV'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'TLC'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'TLC'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V1', 'V1', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V2', 'V2', 'RV'],
#   ['H-18448', 'SPI-MU164699-V2', 'V2', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V1', 'V1', 'RV'],
#   ['H-18444', 'SPI-MU164705-V2', 'V2', 'RV'],
#   ['H-18444', 'SPI-MU164705-V1', 'V1', 'RV'],
#   ['H-18444', 'SPI-MU164705-V2', 'V2', 'TLC'],
#   ['H-18444', 'SPI-MU164705-V1', 'V1', 'TLC'],
#   ['H-18444', 'SPI-MU164705-V5', 'V5', 'TLC'],
#   ...]]

# %%
keywords = [row[1] for row in data_list[0]]
modified_file_names = []

for file_name in keywords:
    parts = file_name.split('-')
    
    # Check if there are at least three parts (two dashes)
    if len(parts) >= 3:
        modified_file_name = '-'.join(parts[:2])  # Join the first two parts with a dash
        modified_file_names.append(modified_file_name)

# modified_file_names now contains the file names without the suffix
print(modified_file_names)
# Out:
# ['SPI-NJ221261', 'SPI-NJ221261', 'SPI-NJ220058', 'SPI-NJ220058', 'SPI-UT173336', 'SPI-UT173336', 'SPI-UT173336', 'SPI-UT173336', 'SPI-UT173336', 'SPI-UT173336', 'SPI-CU300039', 'SPI-CU300039', 'SPI-WF125503', 'SPI-WF125503', 'SPI-WF125503', 'SPI-WF125503', 'SPI-SF184060', 'SPI-SF184060', 'SPI-UT174912', 'SPI-UT174912', 'SPI-UT174904', 'SPI-UT174904', 'SPI-WF125462', 'SPI-WF125462', 'SPI-WF125485', 'SPI-WF125485', 'SPI-WF125473', 'SPI-WF125473', 'SPI-WF125457', 'SPI-WF125457', 'SPI-SF184059', 'SPI-SF184059', 'SPI-SF184059', 'SPI-SF184059', 'SPI-IA210489', 'SPI-IA210489', 'SPI-IA210489', 'SPI-IA210489', 'SPI-IA210489', 'SPI-IA210489', 'SPI-WF125441', 'SPI-WF125441', 'SPI-WF125441', 'SPI-WF125441', 'SPI-WF125434', 'SPI-WF125434', 'SPI-WF125434', 'SPI-WF125434', 'SPI-UT174893', 'SPI-UT174893', 'SPI-UT174893', 'SPI-UT174893', 'SPI-LA193613', 'SPI-LA193613', 'SPI-LA193613', 'SPI-LA193613', 'SPI-IA210577', 'SPI-IA210577', 'SPI-IA210577', 'SPI-IA210577', 'SPI-IA210577', 'SPI-IA210577', 'SPI-IA210654', 'SPI-IA210654', 'SPI-IA210654', 'SPI-IA210654', 'SPI-IA210654', 'SPI-IA210654', 'SPI-SF184032', 'SPI-SF184032', 'SPI-SF184032', 'SPI-SF184032', 'SPI-SF184018', 'SPI-SF184018', 'SPI-WF125429', 'SPI-WF125429', 'SPI-WF125429', 'SPI-WF125429', 'SPI-WF125416', 'SPI-WF125416', 'SPI-WF125416', 'SPI-WF125416', 'SPI-WF125392', 'SPI-WF125392', 'SPI-WF125392', 'SPI-WF125392', 'SPI-SF184026', 'SPI-SF184026', 'SPI-SF184026', 'SPI-SF184026', 'SPI-UT174871', 'SPI-UT174871', 'SPI-LA193637', 'SPI-LA193637', 'SPI-LA193709', 'SPI-LA193709', 'SPI-LA193709', 'SPI-LA193709', 'SPI-LA193649', 'SPI-LA193649', 'SPI-UA241144', 'SPI-UA241144', 'SPI-SF184005', 'SPI-SF184005', 'SPI-SF184005', 'SPI-SF184005', 'SPI-SF183999', 'SPI-SF183999', 'SPI-SF183981', 'SPI-SF183981', 'SPI-WF125408', 'SPI-WF125408', 'SPI-WF125408', 'SPI-WF125408', 'SPI-UT174887', 'SPI-UT174887', 'SPI-SF183977', 'SPI-SF183977', 'SPI-UA241193', 'SPI-UA241193', 'SPI-UA241193', 'SPI-UA241193', 'SPI-UA241187', 'SPI-UA241187', 'SPI-UA241171', 'SPI-UA241171', 'SPI-UA241171', 'SPI-UA241171', 'SPI-UA241160', 'SPI-UA241160', 'SPI-UA241160', 'SPI-UA241160', 'SPI-UA241159', 'SPI-UA241159', 'SPI-UA241132', 'SPI-UA241132', 'SPI-UA241126', 'SPI-UA241126', 'SPI-UA241126', 'SPI-UA241126', 'SPI-UA241118', 'SPI-UA241118', 'SPI-UA241118', 'SPI-UA241118', 'SPI-LA193698', 'SPI-LA193698', 'SPI-LA193654', 'SPI-LA193654', 'SPI-LA193654', 'SPI-LA193654', 'SPI-LA193577', 'SPI-LA193577', 'SPI-LA193676', 'SPI-LA193676', 'SPI-LA193676', 'SPI-LA193676', 'SPI-LA193621', 'SPI-LA193621', 'SPI-LA193621', 'SPI-LA193621', 'SPI-LA193682', 'SPI-LA193682', 'SPI-SF183966', 'SPI-SF183966', 'SPI-SF183966', 'SPI-SF183966', 'SPI-NJ221744', 'SPI-NJ221744', 'SPI-NJ221732', 'SPI-NJ221732', 'SPI-LA193599', 'SPI-LA193599', 'SPI-LA193599', 'SPI-LA193599', 'SPI-LA193566', 'SPI-LA193566', 'SPI-LA193553', 'SPI-LA193553', 'SPI-LA193665', 'SPI-LA193665', 'SPI-LA193665', 'SPI-LA193665', 'SPI-LA193512', 'SPI-LA193512', 'SPI-LA193512', 'SPI-LA193512', 'SPI-LA193489', 'SPI-LA193489', 'SPI-LA193489', 'SPI-LA193489', 'SPI-UI251091', 'SPI-UI251091', 'SPI-UI251091', 'SPI-UI251091', 'SPI-UI251091', 'SPI-SF183953', 'SPI-SF183953', 'SPI-UT174860', 'SPI-UT174860', 'SPI-UT174826', 'SPI-UT174826', 'SPI-NJ221718', 'SPI-NJ221718', 'SPI-NJ221718', 'SPI-NJ221718', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210649', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', 'SPI-IA210637', ...

# %%
# Initialize an empty list to store the common elements
common_elements = []

# Iterate through the elements in the "IS" list
for item in IS:
    # Check if the item exists in the "modified_file_names" list
    if item in modified_file_names:
        common_elements.append(item)

# common_elements now contains the common elements between "IS" and "modified_file_names"
print(common_elements)
# Out:
# ['SPI-JH110088', 'SPI-JH110704', 'SPI-JH112953', 'SPI-JH115247', 'SPI-JH114663', 'SPI-IA210102', 'SPI-JH110280', 'SPI-JH115627', 'SPI-JH112358', 'SPI-IA210599', 'SPI-JH112648', 'SPI-IA210257', 'SPI-IA210637', 'SPI-IA210520', 'SPI-JH114016', 'SPI-JH115778', 'SPI-IA210428', 'SPI-IA210305', 'SPI-IA210273', 'SPI-JH114615', 'SPI-JH111728', 'SPI-IA210196', 'SPI-IA210285', 'SPI-MU163450', 'SPI-JH115593', 'SPI-JH111894', 'SPI-JH112757', 'SPI-MU164552', 'SPI-MU164261', 'SPI-JH114008', 'SPI-JH113081', 'SPI-JH114158', 'SPI-JH111913', 'SPI-JH114303', 'SPI-JH112683', 'SPI-IA210545', 'SPI-JH115746', 'SPI-JH114090', 'SPI-JH111112', 'SPI-JH114588', 'SPI-IA210649', 'SPI-IA210581', 'SPI-JH111791', 'SPI-JH112431', 'SPI-JH112455', 'SPI-JH112708', 'SPI-JH114311', 'SPI-IA210581', 'SPI-MU161671']

# %%
data_list = MIL

for keyword in common_elements:
    info_list_RV = []
    info_list_TLC = []
    info_list_FRC = []

    for idx, row in enumerate(data_list[0]):
        if keyword in row[1]:  # Assuming the second column is at index 1
            print(row[3])
            if "RV" in row[3]:  # Assuming the fourth column is at index 3
                info_list_RV.append(row[2])  # Append the value from the third column
            if "TLC" in row[3]:  # Assuming the fourth column is at index 3
                info_list_TLC.append(row[2])  # Append the value from the third column
            if "FRC" in row[3]:  # Assuming the fourth column is at index 3
                info_list_FRC.append(row[2])  # Append the value from the third column

    if info_list_RV:  # Only proceed if the RV info list is not empty
        unique_values = set(info_list_RV)
        unique_info_list = list(unique_values)
        concatenated_info = ', '.join(unique_info_list)
        RV_info = concatenated_info
        print(f"RV for {keyword}: {RV_info}")
    if info_list_TLC:  # Only proceed if the TLC info list is not empty
        unique_values = set(info_list_TLC)
        unique_info_list = list(unique_values)
        concatenated_info = ', '.join(unique_info_list)
        TLC_info = concatenated_info
        print(f"TLC for {keyword}: {TLC_info}")
    if info_list_FRC:  # Only proceed if the TLC info list is not empty
        unique_values = set(info_list_FRC)
        unique_info_list = list(unique_values)
        concatenated_info = ', '.join(unique_info_list)
        FRC_info = concatenated_info
        print(f"FRC for {keyword}: {FRC_info}\n")

    # Rest of your code (RV_TLC_Image_Pair and updating SO) here, using keyword-specific variables.
# Out:
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# TLC
# TLC
# RV
# RV
# FRC
# RV for SPI-JH110088: LNC, V5, V1, PBV, V2
# TLC for SPI-JH110088: V1, V2, LNC, V5
# FRC for SPI-JH110088: V5
#
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# FRC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV for SPI-JH110704: LNC, V5, V1, PBV, V2
# TLC for SPI-JH110704: V1, V2, LNC, V5
# FRC for SPI-JH110704: V5
#
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV for SPI-JH112953: LNC, PBV, V2, V1
# TLC for SPI-JH112953: V1, V2, LNC
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# FRC
# RV
# RV
# RV
# RV for SPI-JH115247: LNC, V5, V1, PBV, V2
# TLC for SPI-JH115247: V1, V2, LNC, V5
# FRC for SPI-JH115247: V5
#
# TLC
# TLC
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH114663: PBV, V1, V2, LNC
# TLC for SPI-JH114663: V1, V2, LNC, V5
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# FRC
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV for SPI-IA210102: LNC, V5, V1, PBV, V2
# TLC for SPI-IA210102: V1, V2, LNC, V5
# FRC for SPI-IA210102: V5
#
# RV
# TLC
# TLC
# RV
# FRC
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH110280: LNC, V5, V1, PBV, V2
# TLC for SPI-JH110280: V1, V2, LNC, V5
# FRC for SPI-JH110280: V5
#
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH115627: V1, PBV, V2, LNC
# TLC for SPI-JH115627: V1, V2, LNC
# RV
# RV
# RV
# FRC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV for SPI-JH112358: LNC, V5, V1, PBV, V2
# TLC for SPI-JH112358: V1, V2, LNC, V5
# FRC for SPI-JH112358: V5
#
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV for SPI-IA210599: LNC, PBV, V1
# TLC for SPI-IA210599: V1, LNC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# FRC
# TLC
# TLC
# RV for SPI-JH112648: LNC, V5, V1, PBV, V2
# TLC for SPI-JH112648: V1, V2, LNC, V5
# FRC for SPI-JH112648: V5
#
# TLC
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# TLC
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# FRC
# RV
# FRC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV for SPI-IA210257: LNC, V5, V1, PBV, V2
# TLC for SPI-IA210257: V1, V2, LNC, V5
# FRC for SPI-IA210257: V5
#
# RV
# RV
# TLC
# TLC
# RV
# RV
# TLC
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# FRC
# RV
# TLC
# RV
# TLC
# FRC
# RV for SPI-IA210637: PBV, V1, LNC, V5
# TLC for SPI-IA210637: V1, LNC, V5
# FRC for SPI-IA210637: V5
#
# RV
# TLC
# RV
# TLC
# TLC
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV for SPI-IA210520: V1, V2, PBV
# TLC for SPI-IA210520: V1, V2
# TLC
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# FRC
# TLC
# RV
# RV
# RV
# RV for SPI-JH114016: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114016: V1, V2, LNC, V5
# FRC for SPI-JH114016: V5
#
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# FRC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV for SPI-JH115778: LNC, V5, V1, PBV, V2
# TLC for SPI-JH115778: V1, V2, LNC, V5
# FRC for SPI-JH115778: V5
#
# TLC
# RV
# RV
# TLC
# TLC
# TLC
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# FRC
# RV
# TLC
# FRC
# RV
# TLC
# RV for SPI-IA210428: LNC, V5, V1, PBV, V2
# TLC for SPI-IA210428: V1, V2, LNC, V5
# FRC for SPI-IA210428: V5
#
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV for SPI-IA210305: V1, V2, PBV
# TLC for SPI-IA210305: V1, V2
# TLC
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV for SPI-IA210273: LNC, V1, V2, PBV
# TLC for SPI-IA210273: V1, V2, LNC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV for SPI-JH114615: PBV, V2, V1
# TLC for SPI-JH114615: V1, V2
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# FRC
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH111728: LNC, V5, V1, PBV, V2
# TLC for SPI-JH111728: V1, V2, LNC, V5
# FRC for SPI-JH111728: V5
#
# RV
# RV
# FRC
# TLC
# RV
# TLC
# RV
# TLC
# RV
# RV
# TLC
# RV
# TLC
# TLC
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# TLC
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# FRC
# RV for SPI-IA210196: LNC, V5, V1, PBV, V2
# TLC for SPI-IA210196: LNC, V5, V1, PBV, V2
# FRC for SPI-IA210196: V5
#
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV for SPI-IA210285: V1, PBV, V2, LNC
# TLC for SPI-IA210285: V1, V2, LNC
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV for SPI-MU163450: LNC, V5, V1, PBV, V2
# TLC for SPI-MU163450: V1, V2, LNC, V5
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV for SPI-JH115593: PBV, V1, LNC
# TLC for SPI-JH115593: V1, LNC
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# FRC
# TLC
# RV for SPI-JH111894: LNC, V5, V1, PBV, V2
# TLC for SPI-JH111894: V1, V2, LNC, V5
# FRC for SPI-JH111894: V5
#
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# FRC
# RV
# RV
# RV
# RV
# RV for SPI-JH112757: LNC, V5, V1, PBV, V2
# TLC for SPI-JH112757: V1, V2, LNC, V5
# FRC for SPI-JH112757: V5
#
# TLC
# RV
# RV
# TLC
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV for SPI-MU164552: LNC, V5, V1, PBV, V2
# TLC for SPI-MU164552: V1, V2, LNC, V5
# TLC
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV for SPI-MU164261: LNC, V5, V1, PBV, V2
# TLC for SPI-MU164261: V1, V2, LNC, V5
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# FRC
# RV
# TLC
# RV
# RV
# RV for SPI-JH114008: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114008: V1, V2, LNC, V5
# FRC for SPI-JH114008: V5
#
# TLC
# TLC
# RV
# RV
# FRC
# TLC
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH113081: LNC, V5, V1, PBV, V2
# TLC for SPI-JH113081: V1, V2, LNC, V5
# FRC for SPI-JH113081: V5
#
# RV
# RV
# RV
# TLC
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# FRC
# RV
# RV for SPI-JH114158: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114158: V1, V2, LNC, V5
# FRC for SPI-JH114158: V5
#
# RV
# RV
# TLC
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# FRC
# RV for SPI-JH111913: LNC, V5, V1, PBV, V2
# TLC for SPI-JH111913: V1, V2, LNC, V5
# FRC for SPI-JH111913: V5
#
# TLC
# RV
# RV
# FRC
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV for SPI-JH114303: V1, V2, PBV, V5
# TLC for SPI-JH114303: V1, V2, LNC, V5
# FRC for SPI-JH114303: V5
#
# TLC
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# FRC
# TLC
# RV for SPI-JH112683: LNC, V5, V1, PBV, V2
# TLC for SPI-JH112683: V1, V2, LNC, V5
# FRC for SPI-JH112683: V5
#
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV for SPI-IA210545: PBV, V1, LNC
# TLC for SPI-IA210545: V1, LNC
# RV
# TLC
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# FRC
# RV for SPI-JH115746: LNC, V5, V1, PBV, V2
# TLC for SPI-JH115746: V1, V2, LNC, V5
# FRC for SPI-JH115746: V5
#
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# RV
# FRC
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV for SPI-JH114090: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114090: V1, V2, LNC, V5
# FRC for SPI-JH114090: V5
#
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# FRC
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV
# RV
# TLC
# RV
# RV
# RV for SPI-JH111112: LNC, V5, V1, PBV, V2
# TLC for SPI-JH111112: V1, V2, LNC, V5
# FRC for SPI-JH111112: V5
#
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# FRC
# TLC
# RV for SPI-JH114588: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114588: V1, V2, LNC, V5
# FRC for SPI-JH114588: V5
#
# RV
# TLC
# RV
# TLC
# RV
# TLC
# TLC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# FRC
# RV
# FRC
# TLC
# RV for SPI-IA210649: PBV, V1, LNC, V5
# TLC for SPI-IA210649: V1, LNC, V5
# FRC for SPI-IA210649: V5
#
# RV
# TLC
# TLC
# RV
# RV
# TLC
# TLC
# RV
# RV
# TLC
# RV
# RV
# FRC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# FRC
# TLC
# RV for SPI-IA210581: PBV, V1, LNC, V5
# TLC for SPI-IA210581: V1, LNC, V5
# FRC for SPI-IA210581: V5
#
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# TLC
# RV
# FRC
# TLC
# RV
# RV
# RV
# RV
# RV
# RV for SPI-JH111791: LNC, V5, V1, PBV, V2
# TLC for SPI-JH111791: V1, V2, LNC, V5
# FRC for SPI-JH111791: V5
#
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# FRC
# RV
# RV
# RV for SPI-JH112431: LNC, PBV, V1, V5
# TLC for SPI-JH112431: V1, LNC, V5
# FRC for SPI-JH112431: V5
#
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# FRC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV for SPI-JH112455: LNC, PBV, V1, V5
# TLC for SPI-JH112455: V1, LNC, V5
# FRC for SPI-JH112455: V5
#
# FRC
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# TLC
# RV
# RV for SPI-JH112708: LNC, V5, V1, PBV, V2
# TLC for SPI-JH112708: V1, V2, LNC, V5
# FRC for SPI-JH112708: V5
#
# RV
# RV
# RV
# FRC
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# TLC
# RV
# RV
# RV
# RV for SPI-JH114311: LNC, V5, V1, PBV, V2
# TLC for SPI-JH114311: V1, V2, LNC, V5
# FRC for SPI-JH114311: V5
#
# RV
# TLC
# TLC
# RV
# RV
# TLC
# TLC
# RV
# RV
# TLC
# RV
# RV
# FRC
# RV
# RV
# RV
# RV
# RV
# RV
# TLC
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# RV
# FRC
# TLC
# RV for SPI-IA210581: PBV, V1, LNC, V5
# TLC for SPI-IA210581: V1, LNC, V5
# FRC for SPI-IA210581: V5
#
# TLC
# RV
# TLC
# RV
# RV
# RV
# RV
# TLC
# nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\ndnewcomb\Documents\GitHub\RA4-Project\Nate\TablePopulationCode.ipynb Cell 10 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X30sZmlsZQ%3D%3D?line=8'>9</a> if keyword in row[1]:  # Assuming the second column is at index 1
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X30sZmlsZQ%3D%3D?line=9'>10</a>     print(row[3])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X30sZmlsZQ%3D%3D?line=10'>11</a>     if "RV" in row[3]:  # Assuming the fourth column is at index 3
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X30sZmlsZQ%3D%3D?line=11'>12</a>         info_list_RV.append(row[2])  # Append the value from the third column
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X30sZmlsZQ%3D%3D?line=12'>13</a>     if "TLC" in row[3]:  # Assuming the fourth column is at index 3
#
# TypeError: argument of type 'float' is not iterable

# %%
# For single keyword: MIL RV/TLC/FRC Visits
# Takes Keyword, finds index in MIL list, Finds RV, TLC, and FRC Visits
# import time
# t0 = time.time()
# print (time.time()-t0)
keyword = "SPI-JH112953"

data_list = MIL

# 

info_list_RV = []
info_list_TLC = []
info_list_FRC = []

for idx, row in enumerate(data_list[0]):
    if keyword in row[1]:  # Assuming the second column is at index 1
        if "RV" in row[3]:  # Assuming the fourth column is at index 3
            info_list_RV.append(row[2])  # Append the value from the third column
        if "TLC" in row[3]:  # Assuming the fourth column is at index 3
            info_list_TLC.append(row[2])  # Append the value from the third column
        if "FRC" in row[3]:  # Assuming the fourth column is at index 3
            info_list_FRC.append(row[2])  # Append the value from the third column


if info_list_RV:  # Only proceed if the RV info list is not empty
    unique_values = set(info_list_RV)
    unique_info_list = list(unique_values)
    concatenated_info = ', '.join(unique_info_list)
    RV_info = concatenated_info
    print(f"RV: {RV_info}")
if info_list_TLC:  # Only proceed if the TLC info list is not empty
    unique_values = set(info_list_TLC)
    unique_info_list = list(unique_values)
    concatenated_info = ', '.join(unique_info_list)
    TLC_info = concatenated_info
    print(f"TLC: {TLC_info}")
if info_list_FRC:  # Only proceed if the TLC info list is not empty
    unique_values = set(info_list_FRC)
    unique_info_list = list(unique_values)
    concatenated_info = ', '.join(unique_info_list)
    FRC_info = concatenated_info
    print(f"FRC: {FRC_info}")



#########################################################################################################################

#Created an RV/TLC Image Pair String

# Convert RV_info and TLC_info into sets for efficient comparison
rv_set = set(RV_info.split(', '))
tlc_set = set(TLC_info.split(', '))

# Find common values between RV_info and TLC_info
matching_values = rv_set.intersection(tlc_set)

# Create a new string by joining the matching values
RV_TLC_Image_Pair = ', '.join(matching_values)

# Print the new concatenated string
print(f"RV/TLC Image Pair: {RV_TLC_Image_Pair}")

# #########################################################################################################################

for KIndex, row in enumerate(SO):
    if row[0] == keyword:
        SO[KIndex][1].append(RV_info)
        SO[KIndex][2].append(TLC_info)
        SO[KIndex][5].append(RV_TLC_Image_Pair)
        SO[KIndex][7].append(FRC_info)
# Out:
# RV: LNC, PBV, V2, V1
# TLC: V1, V2, LNC
# RV/TLC Image Pair: V1, V2, LNC

# %%
# AP RV/TLC/FRC Visits
#this code gets me the visits for whihc th ekey word is found in AP but it does not determine if it is an RV or a TLC

APK_Vist_TlcRv_Tuples = []
VV = ['V1','V2','V3-PRM','V3-LNC','V5']

import math

for VI, V in enumerate(AP): 
    for RI, R in enumerate(AP[VI]):
        if not isinstance(AP[VI][RI][1], str):
            if math.isnan(AP[VI][RI][1]): continue 
        if keyword in AP[VI][RI][1]:
            APK_Vist_TlcRv_Tuples.append((VI, AP[VI][RI][2]))
print(APK_Vist_TlcRv_Tuples)           


############################################################################################################################

#Finds keyword in SO and appends TLC/RV AP to their respective rows

for KIndex, row in enumerate(SO):
    if row[0] == keyword:
        for i, j in APK_Vist_TlcRv_Tuples:
            if j == 'TLC': SO[KIndex][3].append(VV[i])
            if j == 'RV': SO[KIndex][4].append(VV[i])

# ########################################################
# Out:
# [(1, 'RV'), (1, 'TLC')]

# %%
#### trying to write the SO (data) into excel to see the populated cells 
### where soheil and jensen stopped



import openpyxl

# Your list of strings (replace this with your actual data)
data = SO


# Create a new Excel workbook and select the active sheet
workbook = openpyxl.Workbook()
sheet = workbook.active
data_with_placeholders = [[item if item != [] and isinstance(item, str) else "EMPTY" for item in row] for row in data]
# for row_idx, row_data in enumerate(data, start=1):
#     for col_idx, value in enumerate(row_data, start=1):
#         if isinstance(value, list) and not value:
#             value = "EMPTY"  # Convert empty lists to a placeholder value
#         elif isinstance(value, str) and ',' in value:
#             values_list = [item.strip() for item in value.split(',')]
#             sheet.cell(row=row_idx, column=col_idx).value = values_list
#             continue

#         sheet.cell(row=row_idx, column=col_idx).value = value

for row_index, row_data in enumerate(data, start=1):
    for col_index, value in enumerate(row_data, start=1):
        sheet.cell(row=row_index, column=col_index, value=value[0])

# Save the workbook to a file
workbook.save("./TablesPublication(TEMP)/output.xlsx")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\ndnewcomb\Documents\GitHub\RA4-Project\Nate\TablePopulationCode.ipynb Cell 8 line 2
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X10sZmlsZQ%3D%3D?line=21'>22</a> for row_index, row_data in enumerate(data, start=1):
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X10sZmlsZQ%3D%3D?line=22'>23</a>     for col_index, value in enumerate(row_data, start=1):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X10sZmlsZQ%3D%3D?line=23'>24</a>         sheet.cell(row=row_index, column=col_index, value=value[0])
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X10sZmlsZQ%3D%3D?line=25'>26</a> # Save the workbook to a file
#      <a href='vscode-notebook-cell:/c%3A/Users/ndnewcomb/Documents/GitHub/RA4-Project/Nate/TablePopulationCode.ipynb#X10sZmlsZQ%3D%3D?line=26'>27</a> workbook.save("./TablesPublication(TEMP)/output.xlsx")
#
# IndexError: list index out of range

# %%
#### Problem with searching SPI-IA210545


def create_combined_info_list(keyword, data_list):
    info_list_RV = []
    info_list_TLC = []
    info_list_FRC = []

    for idx, row in enumerate(data_list[0]):
        if keyword in row[1]:  # Assuming the second column is at index 1
            if "RV" in row[3]:  # Assuming the fourth column is at index 3
                info_list_RV.append(row[2])  # Append the value from the third column
            if "TLC" in row[3]:  # Assuming the fourth column is at index 3
                info_list_TLC.append(row[2])  # Append the value from the third column
            if "FRC" in row[3]:  # Assuming the fourth column is at index 3
                info_list_FRC.append(row[2])  # Append the value from the third column
            
    return info_list_RV, info_list_TLC, info_list_FRC


for indexx, keyword in enumerate(IS[0:44]):
    
    data_list = MIL

    info_list_RV, info_list_TLC, info_list_FRC = create_combined_info_list(keyword, data_list)


    if info_list_RV:  # Only proceed if the RV info list is not empty
            unique_values = set(info_list_RV)
            unique_info_list = list(unique_values)
            concatenated_info = ', '.join(unique_info_list)
            RV_info = concatenated_info
            # print(f"RV: {RV_info}")
    if info_list_TLC:  # Only proceed if the TLC info list is not empty
            unique_values = set(info_list_TLC)
            unique_info_list = list(unique_values)
            concatenated_info = ', '.join(unique_info_list)
            TLC_info = concatenated_info
            # print(f"TLC: {TLC_info}")
    if info_list_FRC:  # Only proceed if the TLC info list is not empty
            unique_values = set(info_list_FRC)
            unique_info_list = list(unique_values)
            concatenated_info = ', '.join(unique_info_list)
            FRC_info = concatenated_info
            # print(f"FRC: {FRC_info}")



        #########################################################################################################################

    #Created an RV/TLC Image Pair String

    # Convert RV_info and TLC_info into sets for efficient comparison
    rv_set = set(RV_info.split(', '))
    tlc_set = set(TLC_info.split(', '))

    # Find common values between RV_info and TLC_info
    matching_values = rv_set.intersection(tlc_set)

    # Create a new string by joining the matching values
    RV_TLC_Image_Pair = ', '.join(matching_values)

    # Print the new concatenated string
    # print(f"RV/TLC Image Pair: {RV_TLC_Image_Pair}")


# #########################################################################################################################

    for Kindex, row in enumerate(SO):
        if row[0] == keyword:
            SO[Kindex][2].append(TLC_info)
            SO[Kindex][1].append(RV_info)
            SO[Kindex][7].append(FRC_info)
            SO[Kindex][5].append(RV_TLC_Image_Pair)
    
############################################################################################################################

# Convert numeric values to strings and find the maximum length
max_length = max(len(str(cell)) for row in SO for cell in row)

# Print the matrix with aligned columns
for row in SO:
    row_str = "  ".join(str(cell).ljust(max_length) for cell in row)
    print(row_str)
# Out:
# SPI-...                                                                                                                                           RV IM                                                                                                                                             TLC IM                                                                                                                                            TLC AP                                                                                                                                            RV AP                                                                                                                                             TLC/RV IM                                                                                                                                         TLC/RV AP                                                                                                                                         FRC IM
# SPI-JH110088                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']  ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                ['V1', 'V2', 'V3-LNC', 'V5']                                                                                                                      ['V3-LNC', 'V5']                                                                                                                                  ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH110704                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']  ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                ['V2', 'V3-LNC', 'V5']                                                                                                                            ['V2', 'V3-LNC', 'V5']                                                                                                                            ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112953                                                                                                                                      ['LNC, PBV, V2, V1', 'LNC, PBV, V2, V1', 'LNC, PBV, V2, V1', 'LNC, PBV, V2, V1', 'LNC, PBV, V2, V1', 'LNC, PBV, V2, V1']                          ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                        ['V2']                                                                                                                                            ['V2']                                                                                                                                            ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                        []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH115247                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114663                                                                                                                                      ['PBV, V1, V2, LNC', 'PBV, V1, V2, LNC', 'PBV, V1, V2, LNC', 'PBV, V1, V2, LNC', 'PBV, V1, V2, LNC']                                              ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210102                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH110280                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH115627                                                                                                                                      ['V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC']                                              ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112358                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210599                                                                                                                                      ['LNC, PBV, V1', 'LNC, PBV, V1', 'LNC, PBV, V1', 'LNC, PBV, V1', 'LNC, PBV, V1']                                                                  ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                []                                                                                                                                                ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112648                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210257                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210637                                                                                                                                      ['PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5']                                              ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210520                                                                                                                                      ['V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV']                                                                       ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                []                                                                                                                                                ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114016                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH115778                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210428                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210305                                                                                                                                      ['V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV', 'V1, V2, PBV']                                                                       ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                []                                                                                                                                                ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210273                                                                                                                                      ['LNC, V1, V2, PBV', 'LNC, V1, V2, PBV', 'LNC, V1, V2, PBV', 'LNC, V1, V2, PBV', 'LNC, V1, V2, PBV']                                              ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114615                                                                                                                                      ['PBV, V2, V1', 'PBV, V2, V1', 'PBV, V2, V1', 'PBV, V2, V1', 'PBV, V2, V1']                                                                       ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                []                                                                                                                                                ['V1, V2', 'V1, V2', 'V1, V2', 'V1, V2', 'V1, V2']                                                                                                []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH111728                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210196                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          []                                                                                                                                                []                                                                                                                                                ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210285                                                                                                                                      ['V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC', 'V1, PBV, V2, LNC']                                              ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC', 'V1, V2, LNC']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-MU163450                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH115593                                                                                                                                      ['PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC']                                                                  ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                []                                                                                                                                                ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH111894                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112757                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-MU164552                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-MU164261                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114008                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH113081                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114158                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH111913                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114303                                                                                                                                      ['V1, V2, PBV, V5', 'V1, V2, PBV, V5', 'V1, V2, PBV, V5', 'V1, V2, PBV, V5', 'V1, V2, PBV, V5']                                                   ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, V5', 'V1, V2, V5', 'V1, V2, V5', 'V1, V2, V5', 'V1, V2, V5']                                                                            []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112683                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210545                                                                                                                                      ['PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC', 'PBV, V1, LNC']                                                                  ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                []                                                                                                                                                ['V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC', 'V1, LNC']                                                                                           []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH115746                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114090                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH111112                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH114588                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210649                                                                                                                                      ['PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5']                                              ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-IA210581                                                                                                                                      ['PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5']                                              ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH111791                                                                                                                                      ['LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2', 'LNC, V5, V1, PBV, V2']                          ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                []                                                                                                                                                ['V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5', 'V1, V2, LNC, V5']                                                   []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112431                                                                                                                                      ['LNC, PBV, V1, V5', 'LNC, PBV, V1, V5', 'LNC, PBV, V1, V5', 'LNC, PBV, V1, V5', 'LNC, PBV, V1, V5']                                              ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-JH112455                                                                                                                                      []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []
# SPI-JH112708                                                                                                                                      []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []
# SPI-JH114311                                                                                                                                      []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []
# SPI-IA210581                                                                                                                                      ['PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5', 'PBV, V1, LNC, V5']                                              ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                []                                                                                                                                                ['V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5', 'V1, LNC, V5']                                                                       []                                                                                                                                                ['V5', 'V5', 'V5', 'V5', 'V5']
# SPI-MU161671                                                                                                                                      []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []                                                                                                                                                []

# %%
MIL
# Out:
# [[['H-29737', 'SPI-NJ221261-V5', 'V5', 'RV'],
#   ['H-29737', 'SPI-NJ221261-V5', 'V5', 'TLC'],
#   ['H-19899', 'SPI-NJ220058-V5', 'V5', 'RV'],
#   ['H-19899', 'SPI-NJ220058-V5', 'V5', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V1', 'V1', 'RV'],
#   ['H-19057', 'SPI-UT173336-V5', 'V5', 'RV'],
#   ['H-19057', 'SPI-UT173336-V2', 'V2', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V5', 'V5', 'TLC'],
#   ['H-19057', 'SPI-UT173336-V2', 'V2', 'RV'],
#   ['H-19057', 'SPI-UT173336-V1', 'V1', 'TLC'],
#   ['H-19012', 'SPI-CU300039-V1', 'V1', 'TLC'],
#   ['H-19012', 'SPI-CU300039-V1', 'V1', 'RV'],
#   ['H-19000', 'SPI-WF125503-V5', 'V5', 'RV'],
#   ['H-19000', 'SPI-WF125503-V1', 'V1', 'RV'],
#   ['H-19000', 'SPI-WF125503-V5', 'V5', 'TLC'],
#   ['H-19000', 'SPI-WF125503-V1', 'V1', 'TLC'],
#   ['H-18999', 'SPI-SF184060-V1', 'V1', 'TLC'],
#   ['H-18999', 'SPI-SF184060-V1', 'V1', 'RV'],
#   ['H-18989', 'SPI-UT174912-V1', 'V1', 'RV'],
#   ['H-18989', 'SPI-UT174912-V1', 'V1', 'TLC'],
#   ['H-18988', 'SPI-UT174904-V1', 'V1', 'RV'],
#   ['H-18988', 'SPI-UT174904-V1', 'V1', 'TLC'],
#   ['H-18986', 'SPI-WF125462-V1', 'V1', 'TLC'],
#   ['H-18986', 'SPI-WF125462-V1', 'V1', 'RV'],
#   ['H-18985', 'SPI-WF125485-V1', 'V1', 'TLC'],
#   ['H-18985', 'SPI-WF125485-V1', 'V1', 'RV'],
#   ['H-18984', 'SPI-WF125473-V1', 'V1', 'RV'],
#   ['H-18984', 'SPI-WF125473-V1', 'V1', 'TLC'],
#   ['H-18983', 'SPI-WF125457-V1', 'V1', 'TLC'],
#   ['H-18983', 'SPI-WF125457-V1', 'V1', 'RV'],
#   ['H-18981', 'SPI-SF184059-V5', 'V5', 'TLC'],
#   ['H-18981', 'SPI-SF184059-V1', 'V1', 'RV'],
#   ['H-18981', 'SPI-SF184059-V5', 'V5', 'RV'],
#   ['H-18981', 'SPI-SF184059-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'TLC'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18980', 'SPI-IA210489-V1', 'V1', 'RV'],
#   ['H-18979', 'SPI-WF125441-V1', 'V1', 'TLC'],
#   ['H-18979', 'SPI-WF125441-V1', 'V1', 'RV'],
#   ['H-18979', 'SPI-WF125441-V5', 'V5', 'RV'],
#   ['H-18979', 'SPI-WF125441-V5', 'V5', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V1', 'V1', 'RV'],
#   ['H-18976', 'SPI-WF125434-V1', 'V1', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V5', 'V5', 'TLC'],
#   ['H-18976', 'SPI-WF125434-V5', 'V5', 'RV'],
#   ['H-18975', 'SPI-UT174893-V1', 'V1', 'TLC'],
#   ['H-18975', 'SPI-UT174893-V1', 'V1', 'RV'],
#   ['H-18975', 'SPI-UT174893-V5', 'V5', 'TLC'],
#   ['H-18975', 'SPI-UT174893-V5', 'V5', 'RV'],
#   ['H-18974', 'SPI-LA193613-V5', 'V5', 'RV'],
#   ['H-18974', 'SPI-LA193613-V1', 'V1', 'RV'],
#   ['H-18974', 'SPI-LA193613-V1', 'V1', 'TLC'],
#   ['H-18974', 'SPI-LA193613-V5', 'V5', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'RV'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18973', 'SPI-IA210577-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'RV'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18972', 'SPI-IA210654-V1', 'V1', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V1', 'V1', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V1', 'V1', 'RV'],
#   ['H-18971', 'SPI-SF184032-V5', 'V5', 'TLC'],
#   ['H-18971', 'SPI-SF184032-V5', 'V5', 'RV'],
#   ['H-18970', 'SPI-SF184018-V1', 'V1', 'RV'],
#   ['H-18970', 'SPI-SF184018-V1', 'V1', 'TLC'],
#   ['H-18968', 'SPI-WF125429-V1', 'V1', 'RV'],
#   ['H-18968', 'SPI-WF125429-V5', 'V5', 'RV'],
#   ['H-18968', 'SPI-WF125429-V1', 'V1', 'TLC'],
#   ['H-18968', 'SPI-WF125429-V5', 'V5', 'TLC'],
#   ['H-18967', 'SPI-WF125416-V5', 'V5', 'RV'],
#   ['H-18967', 'SPI-WF125416-V5', 'V5', 'TLC'],
#   ['H-18967', 'SPI-WF125416-V1', 'V1', 'RV'],
#   ['H-18967', 'SPI-WF125416-V1', 'V1', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V1', 'V1', 'RV'],
#   ['H-18966', 'SPI-WF125392-V1', 'V1', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V5', 'V5', 'TLC'],
#   ['H-18966', 'SPI-WF125392-V5', 'V5', 'RV'],
#   ['H-18965', 'SPI-SF184026-V5', 'V5', 'RV'],
#   ['H-18965', 'SPI-SF184026-V1', 'V1', 'RV'],
#   ['H-18965', 'SPI-SF184026-V5', 'V5', 'TLC'],
#   ['H-18965', 'SPI-SF184026-V1', 'V1', 'TLC'],
#   ['H-18964', 'SPI-UT174871-V1', 'V1', 'TLC'],
#   ['H-18964', 'SPI-UT174871-V1', 'V1', 'RV'],
#   ['H-18963', 'SPI-LA193637-V1', 'V1', 'RV'],
#   ['H-18963', 'SPI-LA193637-V1', 'V1', 'TLC'],
#   ['H-18962', 'SPI-LA193709-V1', 'V1', 'TLC'],
#   ['H-18962', 'SPI-LA193709-V5', 'V5', 'RV'],
#   ['H-18962', 'SPI-LA193709-V1', 'V1', 'RV'],
#   ['H-18962', 'SPI-LA193709-V5', 'V5', 'TLC'],
#   ['H-18961', 'SPI-LA193649-V1', 'V1', 'RV'],
#   ['H-18961', 'SPI-LA193649-V1', 'V1', 'TLC'],
#   ['H-18959', 'SPI-UA241144-V1', 'V1', 'RV'],
#   ['H-18959', 'SPI-UA241144-V1', 'V1', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V1', 'V1', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V1', 'V1', 'RV'],
#   ['H-18958', 'SPI-SF184005-V5', 'V5', 'TLC'],
#   ['H-18958', 'SPI-SF184005-V5', 'V5', 'RV'],
#   ['H-18957', 'SPI-SF183999-V1', 'V1', 'TLC'],
#   ['H-18957', 'SPI-SF183999-V1', 'V1', 'RV'],
#   ['H-18956', 'SPI-SF183981-V1', 'V1', 'TLC'],
#   ['H-18956', 'SPI-SF183981-V1', 'V1', 'RV'],
#   ['H-18955', 'SPI-WF125408-V1', 'V1', 'RV'],
#   ['H-18955', 'SPI-WF125408-V5', 'V5', 'TLC'],
#   ['H-18955', 'SPI-WF125408-V1', 'V1', 'TLC'],
#   ['H-18955', 'SPI-WF125408-V5', 'V5', 'RV'],
#   ['H-18954', 'SPI-UT174887-V1', 'V1', 'TLC'],
#   ['H-18954', 'SPI-UT174887-V1', 'V1', 'RV'],
#   ['H-18951', 'SPI-SF183977-V1', 'V1', 'RV'],
#   ['H-18951', 'SPI-SF183977-V1', 'V1', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V5', 'V5', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V1', 'V1', 'TLC'],
#   ['H-18950', 'SPI-UA241193-V5', 'V5', 'RV'],
#   ['H-18950', 'SPI-UA241193-V1', 'V1', 'RV'],
#   ['H-18949', 'SPI-UA241187-V1', 'V1', 'TLC'],
#   ['H-18949', 'SPI-UA241187-V1', 'V1', 'RV'],
#   ['H-18948', 'SPI-UA241171-V5', 'V5', 'RV'],
#   ['H-18948', 'SPI-UA241171-V1', 'V1', 'TLC'],
#   ['H-18948', 'SPI-UA241171-V5', 'V5', 'TLC'],
#   ['H-18948', 'SPI-UA241171-V1', 'V1', 'RV'],
#   ['H-18947', 'SPI-UA241160-V5', 'V5', 'TLC'],
#   ['H-18947', 'SPI-UA241160-V1', 'V1', 'RV'],
#   ['H-18947', 'SPI-UA241160-V5', 'V5', 'RV'],
#   ['H-18947', 'SPI-UA241160-V1', 'V1', 'TLC'],
#   ['H-18945', 'SPI-UA241159-V1', 'V1', 'RV'],
#   ['H-18945', 'SPI-UA241159-V1', 'V1', 'TLC'],
#   ['H-18944', 'SPI-UA241132-V1', 'V1', 'RV'],
#   ['H-18944', 'SPI-UA241132-V1', 'V1', 'TLC'],
#   ['H-18943', 'SPI-UA241126-V1', 'V1', 'TLC'],
#   ['H-18943', 'SPI-UA241126-V5', 'V5', 'RV'],
#   ['H-18943', 'SPI-UA241126-V1', 'V1', 'RV'],
#   ['H-18943', 'SPI-UA241126-V5', 'V5', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V5', 'V5', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V1', 'V1', 'TLC'],
#   ['H-18942', 'SPI-UA241118-V5', 'V5', 'RV'],
#   ['H-18942', 'SPI-UA241118-V1', 'V1', 'RV'],
#   ['H-18941', 'SPI-LA193698-V1', 'V1', 'RV'],
#   ['H-18941', 'SPI-LA193698-V1', 'V1', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V1', 'V1', 'RV'],
#   ['H-18940', 'SPI-LA193654-V5', 'V5', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V1', 'V1', 'TLC'],
#   ['H-18940', 'SPI-LA193654-V5', 'V5', 'RV'],
#   ['H-18939', 'SPI-LA193577-V1', 'V1', 'RV'],
#   ['H-18939', 'SPI-LA193577-V1', 'V1', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V5', 'V5', 'RV'],
#   ['H-18938', 'SPI-LA193676-V1', 'V1', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V5', 'V5', 'TLC'],
#   ['H-18938', 'SPI-LA193676-V1', 'V1', 'RV'],
#   ['H-18937', 'SPI-LA193621-V1', 'V1', 'TLC'],
#   ['H-18937', 'SPI-LA193621-V1', 'V1', 'RV'],
#   ['H-18937', 'SPI-LA193621-V5', 'V5', 'RV'],
#   ['H-18937', 'SPI-LA193621-V5', 'V5', 'TLC'],
#   ['H-18936', 'SPI-LA193682-V1', 'V1', 'TLC'],
#   ['H-18936', 'SPI-LA193682-V1', 'V1', 'RV'],
#   ['H-18935', 'SPI-SF183966-V1', 'V1', 'RV'],
#   ['H-18935', 'SPI-SF183966-V1', 'V1', 'TLC'],
#   ['H-18935', 'SPI-SF183966-V5', 'V5', 'RV'],
#   ['H-18935', 'SPI-SF183966-V5', 'V5', 'TLC'],
#   ['H-18923', 'SPI-NJ221744-V1', 'V1', 'RV'],
#   ['H-18923', 'SPI-NJ221744-V1', 'V1', 'TLC'],
#   ['H-18922', 'SPI-NJ221732-V1', 'V1', 'TLC'],
#   ['H-18922', 'SPI-NJ221732-V1', 'V1', 'RV'],
#   ['H-18919', 'SPI-LA193599-V1', 'V1', 'RV'],
#   ['H-18919', 'SPI-LA193599-V5', 'V5', 'RV'],
#   ['H-18919', 'SPI-LA193599-V1', 'V1', 'TLC'],
#   ['H-18919', 'SPI-LA193599-V5', 'V5', 'TLC'],
#   ['H-18918', 'SPI-LA193566-V1', 'V1', 'TLC'],
#   ['H-18918', 'SPI-LA193566-V1', 'V1', 'RV'],
#   ['H-18917', 'SPI-LA193553-V1', 'V1', 'TLC'],
#   ['H-18917', 'SPI-LA193553-V1', 'V1', 'RV'],
#   ['H-18916', 'SPI-LA193665-V1', 'V1', 'TLC'],
#   ['H-18916', 'SPI-LA193665-V5', 'V5', 'RV'],
#   ['H-18916', 'SPI-LA193665-V1', 'V1', 'RV'],
#   ['H-18916', 'SPI-LA193665-V5', 'V5', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V5', 'V5', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V5', 'V5', 'RV'],
#   ['H-18915', 'SPI-LA193512-V1', 'V1', 'TLC'],
#   ['H-18915', 'SPI-LA193512-V1', 'V1', 'RV'],
#   ['H-18914', 'SPI-LA193489-V1', 'V1', 'TLC'],
#   ['H-18914', 'SPI-LA193489-V5', 'V5', 'RV'],
#   ['H-18914', 'SPI-LA193489-V5', 'V5', 'TLC'],
#   ['H-18914', 'SPI-LA193489-V1', 'V1', 'RV'],
#   ['H-18913', 'SPI-UI251091-V1', 'V1', 'TLC'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'RV'],
#   ['H-18913', 'SPI-UI251091-V1', 'V1', 'RV'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'RV'],
#   ['H-18913', 'SPI-UI251091-V5', 'V5', 'TLC'],
#   ['H-18912', 'SPI-SF183953-V1', 'V1', 'RV'],
#   ['H-18912', 'SPI-SF183953-V1', 'V1', 'TLC'],
#   ['H-18910', 'SPI-UT174860-V1', 'V1', 'RV'],
#   ['H-18910', 'SPI-UT174860-V1', 'V1', 'TLC'],
#   ['H-18905', 'SPI-UT174826-V1', 'V1', 'RV'],
#   ['H-18905', 'SPI-UT174826-V1', 'V1', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V5', 'V5', 'RV'],
#   ['H-18894', 'SPI-NJ221718-V1', 'V1', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V5', 'V5', 'TLC'],
#   ['H-18894', 'SPI-NJ221718-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'TLC'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'RV'],
#   ['H-18893', 'SPI-IA210649-V1', 'V1', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'TLC'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-LNC', 'LNC', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-PBV', 'PBV', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'TLC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'FRC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'RV'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'FRC'],
#   ['H-18893', 'SPI-IA210649-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V1', 'V1', 'TLC'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-LNC', 'LNC', 'TLC'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-PBV', 'PBV', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'FRC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'RV'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'TLC'],
#   ['H-18892', 'SPI-IA210637-V5', 'V5', 'FRC'],
#   ['H-18869', 'SPI-UI251108-V5', 'V5', 'RV'],
#   ['H-18869', 'SPI-UI251108-V1', 'V1', 'RV'],
#   ['H-18869', 'SPI-UI251108-V5', 'V5', 'TLC'],
#   ['H-18869', 'SPI-UI251108-V1', 'V1', 'TLC'],
#   ['H-18866', 'SPI-UT174805-V1', 'V1', 'TLC'],
#   ['H-18866', 'SPI-UT174805-V1', 'V1', 'RV'],
#   ['H-18865', 'SPI-UT174729-V1', 'V1', 'RV'],
#   ['H-18865', 'SPI-UT174729-V1', 'V1', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V5', 'V5', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V1', 'V1', 'TLC'],
#   ['H-18864', 'SPI-UI251063-V1', 'V1', 'RV'],
#   ['H-18864', 'SPI-UI251063-V5', 'V5', 'RV'],
#   ['H-18863', 'SPI-UI251042-V1', 'V1', 'TLC'],
#   ['H-18863', 'SPI-UI251042-V5', 'V5', 'TLC'],
#   ['H-18863', 'SPI-UI251042-V1', 'V1', 'RV'],
#   ['H-18863', 'SPI-UI251042-V5', 'V5', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'RV'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'TLC'],
#   ['H-18862', 'SPI-IA210621-V1', 'V1', 'TLC'],
#   ['H-18861', 'SPI-NJ221726-V1', 'V1', 'RV'],
#   ['H-18861', 'SPI-NJ221726-V1', 'V1', 'TLC'],
#   ['H-18847', 'SPI-UI251056-V1', 'V1', 'RV'],
#   ['H-18847', 'SPI-UI251056-V1', 'V1', 'TLC'],
#   ['H-18845', 'SPI-NJ221638-V1', 'V1', 'RV'],
#   ['H-18845', 'SPI-NJ221638-V1', 'V1', 'TLC'],
#   ['H-18842', 'SPI-UT174818-V1', 'V1', 'TLC'],
#   ['H-18842', 'SPI-UT174818-V1', 'V1', 'RV'],
#   ['H-18840', 'SPI-UT174790-V1', 'V1', 'TLC'],
#   ['H-18840', 'SPI-UT174790-V1', 'V1', 'RV'],
#   ['H-18838', 'SPI-WF125294-V1', 'V1', 'RV'],
#   ['H-18838', 'SPI-WF125294-V1', 'V1', 'TLC'],
#   ['H-18837', 'SPI-UI251030-V5', 'V5', 'RV'],
#   ['H-18837', 'SPI-UI251030-V1', 'V1', 'RV'],
#   ['H-18837', 'SPI-UI251030-V5', 'V5', 'TLC'],
#   ['H-18837', 'SPI-UI251030-V1', 'V1', 'TLC'],
#   ['H-18836', 'SPI-UI251028-V1', 'V1', 'TLC'],
#   ['H-18836', 'SPI-UI251028-V1', 'V1', 'RV'],
#   ['H-18836', 'SPI-UI251028-V5', 'V5', 'RV'],
#   ['H-18836', 'SPI-UI251028-V5', 'V5', 'TLC'],
#   ['H-18835', 'SPI-SF183938-V1', 'V1', 'TLC'],
#   ['H-18835', 'SPI-SF183938-V1', 'V1', 'RV'],
#   ['H-18834', 'SPI-UA241105-V1', 'V1', 'RV'],
#   ['H-18834', 'SPI-UA241105-V1', 'V1', 'TLC'],
#   ['H-18833', 'SPI-NJ221653-V1', 'V1', 'TLC'],
#   ['H-18833', 'SPI-NJ221653-V1', 'V1', 'RV'],
#   ['H-18832', 'SPI-NJ221666-V1', 'V1', 'TLC'],
#   ['H-18832', 'SPI-NJ221666-V1', 'V1', 'RV'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'TLC'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'TLC'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'RV'],
#   ['H-18826', 'SPI-IA210613-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'FRC'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V1', 'V1', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'FRC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'RV'],
#   ['H-18825', 'SPI-IA210538-V5', 'V5', 'TLC'],
#   ['H-18825', 'SPI-IA210538-LNC', 'LNC', 'TLC'],
#   ['H-18824', 'SPI-UT174785-V1', 'V1', 'RV'],
#   ['H-18824', 'SPI-UT174785-V1', 'V1', 'TLC'],
#   ['H-18823', 'SPI-UT174773-V1', 'V1', 'TLC'],
#   ['H-18823', 'SPI-UT174773-V1', 'V1', 'RV'],
#   ['H-18822', 'SPI-UT174757-V1', 'V1', 'RV'],
#   ['H-18822', 'SPI-UT174757-V1', 'V1', 'TLC'],
#   ['H-18821', 'SPI-UT174741-V1', 'V1', 'RV'],
#   ['H-18821', 'SPI-UT174741-V1', 'V1', 'TLC'],
#   ['H-18820', 'SPI-UT174734-V1', 'V1', 'RV'],
#   ['H-18820', 'SPI-UT174734-V1', 'V1', 'TLC'],
#   ['H-18819', 'SPI-UT174716-V1', 'V1', 'TLC'],
#   ['H-18819', 'SPI-UT174716-V1', 'V1', 'RV'],
#   ['H-18818', 'SPI-UI250999-V1', 'V1', 'RV'],
#   ['H-18818', 'SPI-UI250999-V5', 'V5', 'TLC'],
#   ['H-18818', 'SPI-UI250999-V1', 'V1', 'TLC'],
#   ['H-18818', 'SPI-UI250999-V5', 'V5', 'RV'],
#   ['H-18817', 'SPI-UI250953-V1', 'V1', 'RV'],
#   ['H-18817', 'SPI-UI250953-V1', 'V1', 'TLC'],
#   ['H-18816', 'SPI-UI250966-V1', 'V1', 'TLC'],
#   ['H-18816', 'SPI-UI250966-V1', 'V1', 'RV'],
#   ['H-18815', 'SPI-UI250981-V5', 'V5', 'TLC'],
#   ['H-18815', 'SPI-UI250981-V5', 'V5', 'RV'],
#   ['H-18815', 'SPI-UI250981-V1', 'V1', 'RV'],
#   ['H-18815', 'SPI-UI250981-V1', 'V1', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V1', 'V1', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V5', 'V5', 'TLC'],
#   ['H-18814', 'SPI-UI250977-V1', 'V1', 'RV'],
#   ['H-18814', 'SPI-UI250977-V5', 'V5', 'RV'],
#   ['H-18813', 'SPI-WF125370-V1', 'V1', 'RV'],
#   ['H-18813', 'SPI-WF125370-V1', 'V1', 'TLC'],
#   ['H-18812', 'SPI-WF125355-V1', 'V1', 'TLC'],
#   ['H-18812', 'SPI-WF125355-V1', 'V1', 'RV'],
#   ['H-18811', 'SPI-NJ221620-V1', 'V1', 'RV'],
#   ['H-18811', 'SPI-NJ221620-V1', 'V1', 'TLC'],
#   ['H-18810', 'SPI-NJ221595-V1', 'V1', 'TLC'],
#   ['H-18810', 'SPI-NJ221595-V5', 'V5', 'RV'],
#   ['H-18810', 'SPI-NJ221595-V1', 'V1', 'RV'],
#   ['H-18810', 'SPI-NJ221595-V5', 'V5', 'TLC'],
#   ['H-18809', 'SPI-NJ221567-V1', 'V1', 'RV'],
#   ['H-18809', 'SPI-NJ221567-V1', 'V1', 'TLC'],
#   ['H-18750', 'SPI-LA303692-V1', 'V1', 'RV'],
#   ['H-18750', 'SPI-LA303692-V1', 'V1', 'TLC'],
#   ['H-18749', 'SPI-LA193442-V1', 'V1', 'RV'],
#   ['H-18749', 'SPI-LA193442-V1', 'V1', 'TLC'],
#   ['H-18748', 'SPI-SF183920-V2', 'V2', 'RV'],
#   ['H-18748', 'SPI-SF183920-V1', 'V1', 'TLC'],
#   ['H-18748', 'SPI-SF183920-V1', 'V1', 'RV'],
#   ['H-18748', 'SPI-SF183920-V2', 'V2', 'TLC'],
#   ['H-18747', 'SPI-UA241094-V1', 'V1', 'TLC'],
#   ['H-18747', 'SPI-UA241094-V1', 'V1', 'RV'],
#   ['H-18745', 'SPI-UI250920-V1', 'V1', 'RV'],
#   ['H-18745', 'SPI-UI250920-V1', 'V1', 'TLC'],
#   ['H-18745', 'SPI-UI250920-V5', 'V5', 'RV'],
#   ['H-18745', 'SPI-UI250920-V5', 'V5', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V1', 'V1', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V5', 'V5', 'TLC'],
#   ['H-18744', 'SPI-UA241086-V1', 'V1', 'RV'],
#   ['H-18744', 'SPI-UA241086-V5', 'V5', 'RV'],
#   ['H-18743', 'SPI-NJ221511-V1', 'V1', 'TLC'],
#   ['H-18743', 'SPI-NJ221511-V1', 'V1', 'RV'],
#   ['H-18742', 'SPI-NJ221677-V1', 'V1', 'TLC'],
#   ['H-18742', 'SPI-NJ221677-V1', 'V1', 'RV'],
#   ['H-18741', 'SPI-NJ221699-V1', 'V1', 'TLC'],
#   ['H-18741', 'SPI-NJ221699-V1', 'V1', 'RV'],
#   ['H-18740', 'SPI-NJ221552-V1', 'V1', 'TLC'],
#   ['H-18740', 'SPI-NJ221552-V1', 'V1', 'RV'],
#   ['H-18729', 'SPI-NJ220379-V5', 'V5', 'TLC'],
#   ['H-18729', 'SPI-NJ220379-V2', 'V2', 'TLC'],
#   ['H-18729', 'SPI-NJ220379-V5', 'V5', 'RV'],
#   ['H-18729', 'SPI-NJ220379-V2', 'V2', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V1', 'V1', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V5', 'V5', 'RV'],
#   ['H-18728', 'SPI-NJ221580-V5', 'V5', 'TLC'],
#   ['H-18728', 'SPI-NJ221580-V1', 'V1', 'TLC'],
#   ['H-18727', 'SPI-WF125343-V1', 'V1', 'TLC'],
#   ['H-18727', 'SPI-WF125343-V1', 'V1', 'RV'],
#   ['H-18726', 'SPI-SF183912-V1', 'V1', 'RV'],
#   ['H-18726', 'SPI-SF183912-V1', 'V1', 'TLC'],
#   ['H-18726', 'SPI-SF183912-V2', 'V2', 'TLC'],
#   ['H-18726', 'SPI-SF183912-V2', 'V2', 'RV'],
#   ['H-18725', 'SPI-SF183904-V1', 'V1', 'RV'],
#   ['H-18725', 'SPI-SF183904-V1', 'V1', 'TLC'],
#   ['H-18724', 'SPI-SF183844-V1', 'V1', 'RV'],
#   ['H-18724', 'SPI-SF183844-V2', 'V2', 'RV'],
#   ['H-18724', 'SPI-SF183844-V1', 'V1', 'TLC'],
#   ['H-18724', 'SPI-SF183844-V2', 'V2', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V5', 'V5', 'RV'],
#   ['H-18723', 'SPI-SF183893-V1', 'V1', 'RV'],
#   ['H-18723', 'SPI-SF183893-V5', 'V5', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V1', 'V1', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V2', 'V2', 'TLC'],
#   ['H-18723', 'SPI-SF183893-V2', 'V2', 'RV'],
#   ['H-18722', 'SPI-SF183860-V1', 'V1', 'RV'],
#   ['H-18722', 'SPI-SF183860-V1', 'V1', 'TLC'],
#   ['H-18722', 'SPI-SF183860-V5', 'V5', 'TLC'],
#   ['H-18722', 'SPI-SF183860-V5', 'V5', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'RV'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'TLC'],
#   ['H-18721', 'SPI-IA210600-V1', 'V1', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V1', 'V1', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V1', 'V1', 'RV'],
#   ['H-18720', 'SPI-LA193456-V5', 'V5', 'TLC'],
#   ['H-18720', 'SPI-LA193456-V5', 'V5', 'RV'],
#   ['H-18719', 'SPI-LA303688-V1', 'V1', 'RV'],
#   ['H-18719', 'SPI-LA303688-V1', 'V1', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V1', 'V1', 'RV'],
#   ['H-18718', 'SPI-LA193430-V1', 'V1', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V5', 'V5', 'TLC'],
#   ['H-18718', 'SPI-LA193430-V5', 'V5', 'RV'],
#   ['H-18717', 'SPI-LA193371-V1', 'V1', 'RV'],
#   ['H-18717', 'SPI-LA193371-V1', 'V1', 'TLC'],
#   ['H-18716', 'SPI-UA241072-V1', 'V1', 'TLC'],
#   ['H-18716', 'SPI-UA241072-V1', 'V1', 'RV'],
#   ['H-18712', 'SPI-UI250945-V5', 'V5', 'RV'],
#   ['H-18712', 'SPI-UI250945-V1', 'V1', 'TLC'],
#   ['H-18712', 'SPI-UI250945-V5', 'V5', 'TLC'],
#   ['H-18712', 'SPI-UI250945-V1', 'V1', 'RV'],
#   ['H-18711', 'SPI-UA241061-V5', 'V5', 'TLC'],
#   ['H-18711', 'SPI-UA241061-V1', 'V1', 'TLC'],
#   ['H-18711', 'SPI-UA241061-V5', 'V5', 'RV'],
#   ['H-18711', 'SPI-UA241061-V1', 'V1', 'RV'],
#   ['H-18710', 'SPI-UA241040-V5', 'V5', 'TLC'],
#   ['H-18710', 'SPI-UA241040-V1', 'V1', 'RV'],
#   ['H-18710', 'SPI-UA241040-V5', 'V5', 'RV'],
#   ['H-18710', 'SPI-UA241040-V1', 'V1', 'TLC'],
#   ['H-18709', 'SPI-UA241033-V1', 'V1', 'TLC'],
#   ['H-18709', 'SPI-UA241033-V1', 'V1', 'RV'],
#   ['H-18708', 'SPI-WF125331-V1', 'V1', 'TLC'],
#   ['H-18708', 'SPI-WF125331-V1', 'V1', 'RV'],
#   ['H-18707', 'SPI-WF125327-V1', 'V1', 'TLC'],
#   ['H-18707', 'SPI-WF125327-V1', 'V1', 'RV'],
#   ['H-18707', 'SPI-WF125327-V5', 'V5', 'RV'],
#   ['H-18707', 'SPI-WF125327-V5', 'V5', 'TLC'],
#   ['H-18705', 'SPI-UA241058-V1', 'V1', 'TLC'],
#   ['H-18705', 'SPI-UA241058-V1', 'V1', 'RV'],
#   ['H-18704', 'SPI-UA241025-V5', 'V5', 'TLC'],
#   ['H-18704', 'SPI-UA241025-V5', 'V5', 'RV'],
#   ['H-18704', 'SPI-UA241025-V1', 'V1', 'RV'],
#   ['H-18704', 'SPI-UA241025-V1', 'V1', 'TLC'],
#   ['H-18703', 'SPI-UA241017-V1', 'V1', 'TLC'],
#   ['H-18703', 'SPI-UA241017-V1', 'V1', 'RV'],
#   ['H-18702', 'SPI-UA241009-V1', 'V1', 'TLC'],
#   ['H-18702', 'SPI-UA241009-V5', 'V5', 'TLC'],
#   ['H-18702', 'SPI-UA241009-V1', 'V1', 'RV'],
#   ['H-18702', 'SPI-UA241009-V5', 'V5', 'RV'],
#   ['H-18701', 'SPI-UA240996-V2', 'V2', 'TLC'],
#   ['H-18701', 'SPI-UA240996-V1', 'V1', 'RV'],
#   ['H-18701', 'SPI-UA240996-V2', 'V2', 'RV'],
#   ['H-18701', 'SPI-UA240996-V5', 'V5', 'RV'],
#   ['H-18701', 'SPI-UA240996-V1', 'V1', 'TLC'],
#   ['H-18701', 'SPI-UA240996-V5', 'V5', 'TLC'],
#   ['H-18700', 'SPI-UT174697-V1', 'V1', 'RV'],
#   ['H-18700', 'SPI-UT174697-V1', 'V1', 'TLC'],
#   ['H-18699', 'SPI-UT174683-V1', 'V1', 'RV'],
#   ['H-18699', 'SPI-UT174683-V1', 'V1', 'TLC'],
#   ['H-18687', 'SPI-UI250912-V1', 'V1', 'TLC'],
#   ['H-18687', 'SPI-UI250912-V1', 'V1', 'RV'],
#   ['H-18687', 'SPI-UI250912-V5', 'V5', 'RV'],
#   ['H-18687', 'SPI-UI250912-V5', 'V5', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V2', 'V2', 'RV'],
#   ['H-18686', 'SPI-SF183887-V5', 'V5', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V2', 'V2', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V5', 'V5', 'RV'],
#   ['H-18686', 'SPI-SF183887-V1', 'V1', 'TLC'],
#   ['H-18686', 'SPI-SF183887-V1', 'V1', 'RV'],
#   ['H-18685', 'SPI-SF183871-V1', 'V1', 'TLC'],
#   ['H-18685', 'SPI-SF183871-V5', 'V5', 'TLC'],
#   ['H-18685', 'SPI-SF183871-V1', 'V1', 'RV'],
#   ['H-18685', 'SPI-SF183871-V5', 'V5', 'RV'],
#   ['H-18684', 'SPI-UI250893-V1', 'V1', 'RV'],
#   ['H-18684', 'SPI-UI250893-V1', 'V1', 'TLC'],
#   ['H-18683', 'SPI-UI250887-V5', 'V5', 'RV'],
#   ['H-18683', 'SPI-UI250887-V1', 'V1', 'RV'],
#   ['H-18683', 'SPI-UI250887-V5', 'V5', 'TLC'],
#   ['H-18683', 'SPI-UI250887-V1', 'V1', 'TLC'],
#   ['H-18682', 'SPI-UI250826-V1', 'V1', 'TLC'],
#   ['H-18682', 'SPI-UI250826-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'TLC'],
#   ['H-18680', 'SPI-IA210599-PBV', 'PBV', 'RV'],
#   ['H-18680', 'SPI-IA210599-V1', 'V1', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'RV'],
#   ['H-18680', 'SPI-IA210599-LNC', 'LNC', 'TLC'],
#   ['H-18679', 'SPI-JH300602-V1', 'V1', 'RV'],
#   ['H-18679', 'SPI-JH300602-V1', 'V1', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V1', 'V1', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V5', 'V5', 'RV'],
#   ['H-18678', 'SPI-UT174675-V1', 'V1', 'RV'],
#   ['H-18678', 'SPI-UT174675-V2', 'V2', 'RV'],
#   ['H-18678', 'SPI-UT174675-V2', 'V2', 'TLC'],
#   ['H-18678', 'SPI-UT174675-V5', 'V5', 'TLC'],
#   ['H-18677', 'SPI-UI250860-V1', 'V1', 'RV'],
#   ['H-18677', 'SPI-UI250860-V1', 'V1', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V1', 'V1', 'RV'],
#   ['H-18676', 'SPI-UT174650-V2', 'V2', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V1', 'V1', 'TLC'],
#   ['H-18676', 'SPI-UT174650-V2', 'V2', 'RV'],
#   ['H-18673', 'SPI-UI250762-V1', 'V1', 'TLC'],
#   ['H-18673', 'SPI-UI250762-V1', 'V1', 'RV'],
#   ['H-18673', 'SPI-UI250762-V5', 'V5', 'RV'],
#   ['H-18673', 'SPI-UI250762-V5', 'V5', 'TLC'],
#   ['H-18672', 'SPI-NJ221473-V1', 'V1', 'TLC'],
#   ['H-18672', 'SPI-NJ221473-V1', 'V1', 'RV'],
#   ['H-18672', 'SPI-NJ221473-V5', 'V5', 'RV'],
#   ['H-18672', 'SPI-NJ221473-V5', 'V5', 'TLC'],
#   ['H-18666', 'SPI-LA193360-V1', 'V1', 'RV'],
#   ['H-18666', 'SPI-LA193360-V1', 'V1', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V1', 'V1', 'RV'],
#   ['H-18662', 'SPI-LA192862-V1', 'V1', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V2', 'V2', 'TLC'],
#   ['H-18662', 'SPI-LA192862-V2', 'V2', 'RV'],
#   ['H-18661', 'SPI-WF125272-V5', 'V5', 'RV'],
#   ['H-18661', 'SPI-WF125272-V1', 'V1', 'TLC'],
#   ['H-18661', 'SPI-WF125272-V5', 'V5', 'TLC'],
#   ['H-18661', 'SPI-WF125272-V1', 'V1', 'RV'],
#   ['H-18660', 'SPI-UI250818-V5', 'V5', 'TLC'],
#   ['H-18660', 'SPI-UI250818-V1', 'V1', 'RV'],
#   ['H-18660', 'SPI-UI250818-V5', 'V5', 'RV'],
#   ['H-18660', 'SPI-UI250818-V1', 'V1', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V2', 'V2', 'RV'],
#   ['H-18656', 'SPI-LA193387-V1', 'V1', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V2', 'V2', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V1', 'V1', 'RV'],
#   ['H-18656', 'SPI-LA193387-V5', 'V5', 'TLC'],
#   ['H-18656', 'SPI-LA193387-V5', 'V5', 'RV'],
#   ['H-18643', 'SPI-NJ221485-V1', 'V1', 'RV'],
#   ['H-18643', 'SPI-NJ221485-V1', 'V1', 'TLC'],
#   ['H-18642', 'SPI-NJ221355-V1', 'V1', 'RV'],
#   ['H-18642', 'SPI-NJ221355-V1', 'V1', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V5', 'V5', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V1', 'V1', 'TLC'],
#   ['H-18641', 'SPI-WF125319-V5', 'V5', 'RV'],
#   ['H-18641', 'SPI-WF125319-V1', 'V1', 'RV'],
#   ['H-18640', 'SPI-WF125286-V1', 'V1', 'TLC'],
#   ['H-18640', 'SPI-WF125286-V1', 'V1', 'RV'],
#   ['H-18637', 'SPI-UA240984-V1', 'V1', 'TLC'],
#   ['H-18637', 'SPI-UA240984-V5', 'V5', 'TLC'],
#   ['H-18637', 'SPI-UA240984-V1', 'V1', 'RV'],
#   ['H-18637', 'SPI-UA240984-V5', 'V5', 'RV'],
#   ['H-18634', 'SPI-UA240979-V1', 'V1', 'RV'],
#   ['H-18634', 'SPI-UA240979-V1', 'V1', 'TLC'],
#   ['H-18633', 'SPI-UT174669-V1', 'V1', 'RV'],
#   ['H-18633', 'SPI-UT174669-V1', 'V1', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V5', 'V5', 'RV'],
#   ['H-18632', 'SPI-UI250785-V1', 'V1', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V5', 'V5', 'TLC'],
#   ['H-18632', 'SPI-UI250785-V1', 'V1', 'RV'],
#   ['H-18631', 'SPI-SF183859-V1', 'V1', 'TLC'],
#   ['H-18631', 'SPI-SF183859-V1', 'V1', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V1', 'V1', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V1', 'V1', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-LNC', 'LNC', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-LNC', 'LNC', 'TLC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'RV'],
#   ['H-18630', 'SPI-JH112431-V5', 'V5', 'FRC'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18630', 'SPI-JH112431-PBV', 'PBV', 'RV'],
#   ['H-18629', 'SPI-JH112386-V1', 'V1', 'TLC'],
#   ['H-18629', 'SPI-JH112386-V1', 'V1', 'RV'],
#   ['H-18626', 'SPI-UA240807-V5', 'V5', 'TLC'],
#   ['H-18626', 'SPI-UA240807-V1', 'V1', 'RV'],
#   ['H-18626', 'SPI-UA240807-V5', 'V5', 'RV'],
#   ['H-18626', 'SPI-UA240807-V2', 'V2', 'RV'],
#   ['H-18626', 'SPI-UA240807-V1', 'V1', 'TLC'],
#   ['H-18626', 'SPI-UA240807-V2', 'V2', 'TLC'],
#   ['H-18623', 'SPI-JH115631-V1', 'V1', 'TLC'],
#   ['H-18623', 'SPI-JH115631-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'TLC'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18621', 'SPI-IA210581-V1', 'V1', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'FRC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'TLC'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'RV'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-PBV', 'PBV', 'RV'],
#   ['H-18621', 'SPI-IA210581-V5', 'V5', 'FRC'],
#   ['H-18621', 'SPI-IA210581-LNC', 'LNC', 'TLC'],
#   ['H-18598', 'SPI-WF125233-V1', 'V1', 'RV'],
#   ['H-18598', 'SPI-WF125233-V1', 'V1', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V5', 'V5', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V1', 'V1', 'TLC'],
#   ['H-18596', 'SPI-SF183826-V5', 'V5', 'RV'],
#   ['H-18596', 'SPI-SF183826-V1', 'V1', 'RV'],
#   ['H-18595', 'SPI-UA240968-V1', 'V1', 'TLC'],
#   ['H-18595', 'SPI-UA240968-V1', 'V1', 'RV'],
#   ['H-18594', 'SPI-WF125240-V1', 'V1', 'RV'],
#   ['H-18594', 'SPI-WF125240-V5', 'V5', 'TLC'],
#   ['H-18594', 'SPI-WF125240-V1', 'V1', 'TLC'],
#   ['H-18594', 'SPI-WF125240-V5', 'V5', 'RV'],
#   ['H-18593', 'SPI-UI250757-V1', 'V1', 'TLC'],
#   ['H-18593', 'SPI-UI250757-V1', 'V1', 'RV'],
#   ['H-18593', 'SPI-UI250757-V5', 'V5', 'RV'],
#   ['H-18593', 'SPI-UI250757-V5', 'V5', 'TLC'],
#   ['H-18592', 'SPI-UI250675-V1', 'V1', 'RV'],
#   ['H-18592', 'SPI-UI250675-V1', 'V1', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V5', 'V5', 'RV'],
#   ['H-18591', 'SPI-UI250741-V5', 'V5', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V1', 'V1', 'TLC'],
#   ['H-18591', 'SPI-UI250741-V1', 'V1', 'RV'],
#   ['H-18586', 'SPI-JH112464-V1', 'V1', 'TLC'],
#   ['H-18586', 'SPI-JH112464-V1', 'V1', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V1', 'V1', 'TLC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V1', 'V1', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'FRC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-V5', 'V5', 'TLC'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-PBV', 'PBV', 'RV'],
#   ['H-18585', 'SPI-JH112455-LNC', 'LNC', 'TLC'],
#   ['H-18585', 'SPI-JH112455-LNC', 'LNC', 'RV'],
#   ['H-18584', 'SPI-JH112443-V1', 'V1', 'RV'],
#   ['H-18584', 'SPI-JH112443-V1', 'V1', 'TLC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'FRC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'TLC'],
#   ['H-18584', 'SPI-JH112443-V5', 'V5', 'RV'],
#   ['H-18581', 'SPI-SF183818-V1', 'V1', 'TLC'],
#   ['H-18581', 'SPI-SF183818-V1', 'V1', 'RV'],
#   ['H-18581', 'SPI-SF183818-V5', 'V5', 'TLC'],
#   ['H-18581', 'SPI-SF183818-V5', 'V5', 'RV'],
#   ['H-18580', 'SPI-UI250716-V1', 'V1', 'TLC'],
#   ['H-18580', 'SPI-UI250716-V1', 'V1', 'RV'],
#   ['H-18580', 'SPI-UI250716-V5', 'V5', 'RV'],
#   ['H-18580', 'SPI-UI250716-V5', 'V5', 'TLC'],
#   ['H-18579', 'SPI-NJ221183-V1', 'V1', 'RV'],
#   ['H-18579', 'SPI-NJ221183-V5', 'V5', 'RV'],
#   ['H-18579', 'SPI-NJ221183-V1', 'V1', 'TLC'],
#   ['H-18579', 'SPI-NJ221183-V5', 'V5', 'TLC'],
#   ['H-18578', 'SPI-NJ221434-V1', 'V1', 'TLC'],
#   ['H-18578', 'SPI-NJ221434-V1', 'V1', 'RV'],
#   ['H-18577', 'SPI-NJ221441-V1', 'V1', 'TLC'],
#   ['H-18577', 'SPI-NJ221441-V1', 'V1', 'RV'],
#   ['H-18576', 'SPI-UI250729-V1', 'V1', 'RV'],
#   ['H-18576', 'SPI-UI250729-V1', 'V1', 'TLC'],
#   ['H-18576', 'SPI-UI250729-V5', 'V5', 'RV'],
#   ['H-18576', 'SPI-UI250729-V5', 'V5', 'TLC'],
#   ['H-18575', 'SPI-SF183785-V1', 'V1', 'RV'],
#   ['H-18575', 'SPI-SF183785-V5', 'V5', 'RV'],
#   ['H-18575', 'SPI-SF183785-V1', 'V1', 'TLC'],
#   ['H-18575', 'SPI-SF183785-V5', 'V5', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V2', 'V2', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V1', 'V1', 'RV'],
#   ['H-18574', 'SPI-UA240951-V2', 'V2', 'RV'],
#   ['H-18574', 'SPI-UA240951-V1', 'V1', 'TLC'],
#   ['H-18574', 'SPI-UA240951-V5', 'V5', 'RV'],
#   ['H-18574', 'SPI-UA240951-V5', 'V5', 'TLC'],
#   ['H-18573', 'SPI-WF125150-V1', 'V1', 'RV'],
#   ['H-18573', 'SPI-WF125150-V1', 'V1', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V1', 'V1', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V1', 'V1', 'RV'],
#   ['H-18572', 'SPI-UT174648-V2', 'V2', 'TLC'],
#   ['H-18572', 'SPI-UT174648-V2', 'V2', 'RV'],
#   ['H-18571', 'SPI-JH112419-V1', 'V1', 'RV'],
#   ['H-18571', 'SPI-JH112419-V1', 'V1', 'TLC'],
#   ['H-18570', 'SPI-JH112333-V1', 'V1', 'RV'],
#   ['H-18570', 'SPI-JH112333-V1', 'V1', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V1', 'V1', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V1', 'V1', 'RV'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'TLC'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'RV'],
#   ['H-18569', 'SPI-JH112394-V5', 'V5', 'FRC'],
#   ['H-18555', 'SPI-UA240947-V1', 'V1', 'TLC'],
#   ['H-18555', 'SPI-UA240947-V1', 'V1', 'RV'],
#   ['H-18554', 'SPI-UA240910-V1', 'V1', 'RV'],
#   ['H-18554', 'SPI-UA240910-V2', 'V2', 'TLC'],
#   ['H-18554', 'SPI-UA240910-V1', 'V1', 'TLC'],
#   ['H-18554', 'SPI-UA240910-V2', 'V2', 'RV'],
#   ['H-18552', 'SPI-JH112361-V2', 'V2', 'RV'],
#   ['H-18552', 'SPI-JH112361-V1', 'V1', 'RV'],
#   ['H-18552', 'SPI-JH112361-V2', 'V2', 'TLC'],
#   ['H-18552', 'SPI-JH112361-V1', 'V1', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'FRC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V5', 'V5', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-V1', 'V1', 'TLC'],
#   ['H-18551', 'SPI-JH112358-V1', 'V1', 'RV'],
#   ['H-18551', 'SPI-JH112358-V2', 'V2', 'RV'],
#   ['H-18551', 'SPI-JH112358-V2', 'V2', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-LNC', 'LNC', 'RV'],
#   ['H-18551', 'SPI-JH112358-LNC', 'LNC', 'TLC'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18551', 'SPI-JH112358-PBV', 'PBV', 'RV'],
#   ['H-18550', 'SPI-JH115670-V2', 'V2', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V1', 'V1', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V2', 'V2', 'RV'],
#   ['H-18550', 'SPI-JH115670-V1', 'V1', 'RV'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'RV'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'TLC'],
#   ['H-18550', 'SPI-JH115670-V5', 'V5', 'FRC'],
#   ['H-18549', 'SPI-JH300583-V1', 'V1', 'TLC'],
#   ['H-18549', 'SPI-JH300583-V1', 'V1', 'RV'],
#   ['H-18548', 'SPI-JH112317-V1', 'V1', 'RV'],
#   ['H-18548', 'SPI-JH112317-V1', 'V1', 'TLC'],
#   ['H-18547', 'SPI-JH112207-V1', 'V1', 'RV'],
#   ['H-18547', 'SPI-JH112207-V1', 'V1', 'TLC'],
#   ['H-18545', 'SPI-LA193344-V1', 'V1', 'TLC'],
#   ['H-18545', 'SPI-LA193344-V1', 'V1', 'RV'],
#   ['H-18516', 'SPI-MU164732-V1', 'V1', 'TLC'],
#   ['H-18516', 'SPI-MU164732-V1', 'V1', 'RV'],
#   ['H-18516', 'SPI-MU164732-V5', 'V5', 'TLC'],
#   ['H-18516', 'SPI-MU164732-V5', 'V5', 'RV'],
#   ['H-18515', 'SPI-MU164718-V1', 'V1', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V1', 'V1', 'RV'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'RV'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'TLC'],
#   ['H-18515', 'SPI-MU164718-V5', 'V5', 'RV'],
#   ['H-18514', 'SPI-MU164726-V1', 'V1', 'TLC'],
#   ['H-18514', 'SPI-MU164726-V1', 'V1', 'RV'],
#   ['H-18514', 'SPI-MU164726-V5', 'V5', 'TLC'],
#   ['H-18514', 'SPI-MU164726-V5', 'V5', 'RV'],
#   ['H-18513', 'SPI-JH112289-V1', 'V1', 'TLC'],
#   ['H-18513', 'SPI-JH112289-V1', 'V1', 'RV'],
#   ['H-18512', 'SPI-JH112325-V1', 'V1', 'TLC'],
#   ['H-18512', 'SPI-JH112325-V1', 'V1', 'RV'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'TLC'],
#   ['H-18511', 'SPI-JH112291-V1', 'V1', 'TLC'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'RV'],
#   ['H-18511', 'SPI-JH112291-V5', 'V5', 'FRC'],
#   ['H-18511', 'SPI-JH112291-V1', 'V1', 'RV'],
#   ['H-18510', 'SPI-JH112195-V1', 'V1', 'RV'],
#   ['H-18510', 'SPI-JH112195-V1', 'V1', 'TLC'],
#   ['H-18509', 'SPI-JH115917-V1', 'V1', 'TLC'],
#   ['H-18509', 'SPI-JH115917-V1', 'V1', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V5', 'V5', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V1', 'V1', 'RV'],
#   ['H-18508', 'SPI-NJ221429-V5', 'V5', 'TLC'],
#   ['H-18508', 'SPI-NJ221429-V1', 'V1', 'TLC'],
#   ['H-18507', 'SPI-NJ221416-V5', 'V5', 'RV'],
#   ['H-18507', 'SPI-NJ221416-V5', 'V5', 'TLC'],
#   ['H-18507', 'SPI-NJ221416-V1', 'V1', 'RV'],
#   ['H-18507', 'SPI-NJ221416-V1', 'V1', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V5', 'V5', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V1', 'V1', 'TLC'],
#   ['H-18506', 'SPI-NJ221364-V5', 'V5', 'RV'],
#   ['H-18506', 'SPI-NJ221364-V1', 'V1', 'RV'],
#   ['H-18505', 'SPI-NJ221225-V1', 'V1', 'RV'],
#   ['H-18505', 'SPI-NJ221225-V1', 'V1', 'TLC'],
#   ['H-18504', 'SPI-NJ221370-V1', 'V1', 'RV'],
#   ['H-18504', 'SPI-NJ221370-V1', 'V1', 'TLC'],
#   ['H-18503', 'SPI-NJ221294-V1', 'V1', 'TLC'],
#   ['H-18503', 'SPI-NJ221294-V1', 'V1', 'RV'],
#   ['H-18502', 'SPI-UT174636-V1', 'V1', 'TLC'],
#   ['H-18502', 'SPI-UT174636-V1', 'V1', 'RV'],
#   ['H-18502', 'SPI-UT174636-V2', 'V2', 'RV'],
#   ['H-18502', 'SPI-UT174636-V2', 'V2', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V2', 'V2', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V1', 'V1', 'TLC'],
#   ['H-18501', 'SPI-UT174601-V2', 'V2', 'RV'],
#   ['H-18501', 'SPI-UT174601-V1', 'V1', 'RV'],
#   ['H-18500', 'SPI-UT174598-V1', 'V1', 'TLC'],
#   ['H-18500', 'SPI-UT174598-V1', 'V1', 'RV'],
#   ['H-18500', 'SPI-UT174598-V2', 'V2', 'TLC'],
#   ['H-18500', 'SPI-UT174598-V2', 'V2', 'RV'],
#   ['H-18499', 'SPI-SF183805-V1', 'V1', 'RV'],
#   ['H-18499', 'SPI-SF183805-V2', 'V2', 'TLC'],
#   ['H-18499', 'SPI-SF183805-V1', 'V1', 'TLC'],
#   ['H-18499', 'SPI-SF183805-V2', 'V2', 'RV'],
#   ['H-18498', 'SPI-SF183790-V1', 'V1', 'RV'],
#   ['H-18498', 'SPI-SF183790-V2', 'V2', 'TLC'],
#   ['H-18498', 'SPI-SF183790-V1', 'V1', 'TLC'],
#   ['H-18498', 'SPI-SF183790-V5', 'V5', 'RV'],
#   ['H-18498', 'SPI-SF183790-V2', 'V2', 'RV'],
#   ['H-18498', 'SPI-SF183790-V5', 'V5', 'TLC'],
#   ['H-18497', 'SPI-WF125217-V1', 'V1', 'TLC'],
#   ['H-18497', 'SPI-WF125217-V1', 'V1', 'RV'],
#   ['H-18496', 'SPI-WF125209-V1', 'V1', 'TLC'],
#   ['H-18496', 'SPI-WF125209-V2', 'V2', 'TLC'],
#   ['H-18496', 'SPI-WF125209-V1', 'V1', 'RV'],
#   ['H-18496', 'SPI-WF125209-V2', 'V2', 'RV'],
#   ['H-18496', 'SPI-WF125209-V5', 'V5', 'RV'],
#   ['H-18496', 'SPI-WF125209-V5', 'V5', 'TLC'],
#   ['H-18495', 'SPI-WF125197-V1', 'V1', 'RV'],
#   ['H-18495', 'SPI-WF125197-V5', 'V5', 'RV'],
#   ['H-18495', 'SPI-WF125197-V1', 'V1', 'TLC'],
#   ['H-18495', 'SPI-WF125197-V5', 'V5', 'TLC'],
#   ['H-18494', 'SPI-WF125148-V1', 'V1', 'RV'],
#   ['H-18494', 'SPI-WF125148-V1', 'V1', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V1', 'V1', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V1', 'V1', 'RV'],
#   ['H-18493', 'SPI-WF124740-V2', 'V2', 'RV'],
#   ['H-18493', 'SPI-WF124740-V2', 'V2', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V5', 'V5', 'TLC'],
#   ['H-18493', 'SPI-WF124740-V5', 'V5', 'RV'],
#   ['H-18492', 'SPI-WF125183-V5', 'V5', 'TLC'],
#   ['H-18492', 'SPI-WF125183-V1', 'V1', 'TLC'],
#   ['H-18492', 'SPI-WF125183-V5', 'V5', 'RV'],
#   ['H-18492', 'SPI-WF125183-V1', 'V1', 'RV'],
#   ['H-18491', 'SPI-UA240935-V1', 'V1', 'TLC'],
#   ['H-18491', 'SPI-UA240935-V1', 'V1', 'RV'],
#   ['H-18491', 'SPI-UA240935-V2', 'V2', 'RV'],
#   ['H-18491', 'SPI-UA240935-V2', 'V2', 'TLC'],
#   ['H-18490', 'SPI-UA240923-V1', 'V1', 'TLC'],
#   ['H-18490', 'SPI-UA240923-V1', 'V1', 'RV'],
#   ['H-18489', 'SPI-UA240902-V2', 'V2', 'RV'],
#   ['H-18489', 'SPI-UA240902-V1', 'V1', 'TLC'],
#   ['H-18489', 'SPI-UA240902-V2', 'V2', 'TLC'],
#   ['H-18489', 'SPI-UA240902-V5', 'V5', 'RV'],
#   ['H-18489', 'SPI-UA240902-V1', 'V1', 'RV'],
#   ['H-18489', 'SPI-UA240902-V5', 'V5', 'TLC'],
#   ['H-18488', 'SPI-UI250708-V1', 'V1', 'TLC'],
#   ['H-18488', 'SPI-UI250708-V1', 'V1', 'RV'],
#   ['H-18487', 'SPI-UI250697-V1', 'V1', 'RV'],
#   ['H-18487', 'SPI-UI250697-V2', 'V2', 'TLC'],
#   ['H-18487', 'SPI-UI250697-V2', 'V2', 'RV'],
#   ['H-18487', 'SPI-UI250697-V1', 'V1', 'TLC'],
#   ['H-18486', 'SPI-UI250683-V1', 'V1', 'TLC'],
#   ['H-18486', 'SPI-UI250683-V1', 'V1', 'RV'],
#   ['H-18485', 'SPI-UI250669-V1', 'V1', 'TLC'],
#   ['H-18485', 'SPI-UI250669-V2', 'V2', 'TLC'],
#   ['H-18485', 'SPI-UI250669-V1', 'V1', 'RV'],
#   ['H-18485', 'SPI-UI250669-V2', 'V2', 'RV'],
#   ['H-18484', 'SPI-UI250648-V1', 'V1', 'TLC'],
#   ['H-18484', 'SPI-UI250648-V1', 'V1', 'RV'],
#   ['H-18483', 'SPI-UI250622-V1', 'V1', 'TLC'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'TLC'],
#   ['H-18483', 'SPI-UI250622-V1', 'V1', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'RV'],
#   ['H-18483', 'SPI-UI250622-V2', 'V2', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V1', 'V1', 'RV'],
#   ['H-18482', 'SPI-UI250636-V2', 'V2', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V1', 'V1', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V2', 'V2', 'RV'],
#   ['H-18482', 'SPI-UI250636-V5', 'V5', 'TLC'],
#   ['H-18482', 'SPI-UI250636-V5', 'V5', 'RV'],
#   ['H-18481', 'SPI-CU105112-V1', 'V1', 'RV'],
#   ['H-18481', 'SPI-CU105112-V5', 'V5', 'RV'],
#   ['H-18481', 'SPI-CU105112-V2', 'V2', 'TLC'],
#   ['H-18481', 'SPI-CU105112-V1', 'V1', 'TLC'],
#   ['H-18481', 'SPI-CU105112-V2', 'V2', 'RV'],
#   ['H-18481', 'SPI-CU105112-V5', 'V5', 'TLC'],
#   ['H-18480', 'SPI-CU105104-V1', 'V1', 'RV'],
#   ['H-18480', 'SPI-CU105104-V1', 'V1', 'TLC'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'TLC'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'RV'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'RV'],
#   ['H-18479', 'SPI-IA210553-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V1', 'V1', 'TLC'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'RV'],
#   ['H-18478', 'SPI-IA210566-V2', 'V2', 'TLC'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'RV'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'TLC'],
#   ['H-18477', 'SPI-IA210545-LNC', 'LNC', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-V1', 'V1', 'TLC'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18477', 'SPI-IA210545-PBV', 'PBV', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'TLC'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'RV'],
#   ['H-18476', 'SPI-IA210512-V1', 'V1', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V1', 'V1', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V2', 'V2', 'RV'],
#   ['H-18448', 'SPI-MU164699-V2', 'V2', 'TLC'],
#   ['H-18448', 'SPI-MU164699-V1', 'V1', 'RV'],
#   ['H-18444', 'SPI-MU164705-V2', 'V2', 'RV'],
#   ['H-18444', 'SPI-MU164705-V1', 'V1', 'RV'],
#   ['H-18444', 'SPI-MU164705-V2', 'V2', 'TLC'],
#   ['H-18444', 'SPI-MU164705-V1', 'V1', 'TLC'],
#   ['H-18444', 'SPI-MU164705-V5', 'V5', 'TLC'],
#   ...]]

# %%
MIL_second_column = [MIL[0][i][1] for i in range(len(MIL[0]))]

# %%
import re
# 15 instances of SPI 210545 so fix that 
# Your list of strings


# Define the regular expression pattern
pattern = r'^SPI-[A-Z]{2}\d{6}-[A-Za-z0-9]+$'

# Iterate through the list and check for non-conforming entries
non_conforming_entries = [s for s in MIL_second_column if not re.match(pattern, s)]

# Print the non-conforming entries
for entry in non_conforming_entries:
    print(entry)

# %%
MIL_second_column = [MIL[0][i][1] for i in range(len(MIL[0]))]
